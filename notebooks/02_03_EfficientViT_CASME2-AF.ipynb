# %%
# @title Cell 1: CASME II EfficientViT Infrastructure Configuration

# File: 02_03_EfficientViT_Direct_Optimized_Baseline_Cell1.py
# Location: experiments/02_03_EfficientViT_Direct_Baseline.ipynb
# Purpose: Optimized EfficientViT for CASME II micro-expression recognition with cascaded group attention and advanced class weight optimization

# Mount Google Drive
from google.colab import drive
print("=" * 60)
print("CASME II EFFICIENTVIT OPTIMIZED BASELINE INFRASTRUCTURE")
print("=" * 60)
print("\n[1] Mounting Google Drive...")
drive.mount('/content/drive')
print("Google Drive mounted successfully")

print("\n[2] Importing required libraries...")
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
import torchvision.transforms as transforms
import timm
import json
import os
import numpy as np
import pandas as pd
from PIL import Image
import time
from sklearn.metrics import f1_score, precision_recall_fscore_support, accuracy_score
import warnings
warnings.filterwarnings('ignore')

# Project paths configuration - updated for EfficientViT
PROJECT_ROOT = "/content/drive/MyDrive/RESEARCH-WORKSPACE/ACTIVE-PROJECTS/Thesis_MER_Project"
DATASET_ROOT = f"{PROJECT_ROOT}/datasets/processed_casme2/data_split_v1"
CHECKPOINT_ROOT = f"{PROJECT_ROOT}/models/02_03_efficientvit_casme2-af"
RESULTS_ROOT = f"{PROJECT_ROOT}/results/02_03_efficientvit_casme2-af"

# Load CASME II dataset metadata - preserved existing paths
METADATA_TRAIN = f"{DATASET_ROOT}/split_metadata.json"
PROCESSING_SUMMARY = f"{DATASET_ROOT}/processing_summary.json"

print("CASME II EfficientViT Optimized Baseline - Infrastructure Configuration")
print("======================================================================")

# Load dataset metadata
print("Loading CASME II dataset metadata...")
with open(METADATA_TRAIN, 'r') as f:
    casme2_metadata = json.load(f)

with open(PROCESSING_SUMMARY, 'r') as f:
    processing_info = json.load(f)

print(f"Dataset: {processing_info['dataset']}")
print(f"Total samples: {processing_info['total_samples']}")
print(f"Split strategy: {processing_info['split_strategy']}")

# =====================================================
# ADVANCED EXPERIMENT CONFIGURATION - EfficientViT Optimized Parameters
# =====================================================

# FOCAL LOSS CONFIGURATION - Toggle and Advanced Parameters
USE_FOCAL_LOSS = True  # Set True to enable Focal Loss, False for CrossEntropy
FOCAL_LOSS_GAMMA = 2.0  # Focal loss focusing parameter (typically 1.0 - 3.0)

# OPTIMIZED CLASS WEIGHTS CONFIGURATION - Inverse Square Root Frequency Approach
# CASME II classes: ['others', 'disgust', 'happiness', 'repression', 'surprise', 'sadness', 'fear']
# Train distribution: [99, 63, 32, 27, 25, 7, 2] - inverse sqrt frequency approach

# CrossEntropy Loss - Optimized inverse square root frequency weights
CROSSENTROPY_CLASS_WEIGHTS = [1.00, 1.25, 1.76, 1.91, 1.99, 3.76, 7.04]

# Focal Loss - Normalized per-class alpha values (sum = 1.0)
FOCAL_LOSS_ALPHA_WEIGHTS = [0.053, 0.067, 0.094, 0.102, 0.106, 0.201, 0.376]

# EFFICIENTVIT MODEL CONFIGURATION - Support M4 and M5 variants
EFFICIENTVIT_MODEL_VARIANT = 'm5'  # Options: 'm4' or 'm5'

# Dynamic EfficientViT model selection based on variant
if EFFICIENTVIT_MODEL_VARIANT == 'm4':
    EFFICIENTVIT_MODEL_NAME = 'efficientvit_m4.r224_in1k'
    EXPECTED_EMBED_DIMS = [128, 256, 384]
    EXPECTED_FINAL_DIM = 384
    EXPECTED_PARAMS = 24.0  # Million parameters
    print("Using EfficientViT-M4 for balanced capability-efficiency micro-expression analysis")
elif EFFICIENTVIT_MODEL_VARIANT == 'm5':
    EFFICIENTVIT_MODEL_NAME = 'efficientvit_m5.r224_in1k'
    EXPECTED_EMBED_DIMS = [192, 288, 384]
    EXPECTED_FINAL_DIM = 384
    EXPECTED_PARAMS = 12.5  # Million parameters
    print("Using EfficientViT-M5 for optimized efficiency micro-expression recognition")
else:
    raise ValueError(f"Unsupported EFFICIENTVIT_MODEL_VARIANT: {EFFICIENTVIT_MODEL_VARIANT}")

# Display experiment configuration
print("\n" + "=" * 50)
print("OPTIMIZED EXPERIMENT CONFIGURATION")
print("=" * 50)
print(f"Loss Function: {'Focal Loss' if USE_FOCAL_LOSS else 'CrossEntropy Loss'}")
if USE_FOCAL_LOSS:
    print(f"  Gamma: {FOCAL_LOSS_GAMMA}")
    print(f"  Alpha Weights (per-class): {FOCAL_LOSS_ALPHA_WEIGHTS}")
    print(f"  Alpha Sum Validation: {sum(FOCAL_LOSS_ALPHA_WEIGHTS):.3f}")
else:
    print(f"  Class Weights (inverse sqrt freq): {CROSSENTROPY_CLASS_WEIGHTS}")
print(f"EfficientViT Model: {EFFICIENTVIT_MODEL_NAME}")
print(f"Variant: {EFFICIENTVIT_MODEL_VARIANT.upper()}")
print(f"Embed Dimensions: {EXPECTED_EMBED_DIMS}")
print(f"Final Dimension: {EXPECTED_FINAL_DIM}")
print(f"Expected Parameters: {EXPECTED_PARAMS}M")
print("=" * 50)

# Enhanced GPU configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
gpu_name = torch.cuda.get_device_name(0) if torch.cuda.is_available() else "CPU"
gpu_memory = torch.cuda.get_device_properties(0).total_memory / 1e9 if torch.cuda.is_available() else 0

print(f"\nDevice: {device}")
print(f"GPU: {gpu_name} ({gpu_memory:.1f} GB)")

# Hardware-optimized batch size for 384px input with EfficientViT
if 'A100' in gpu_name:
    BATCH_SIZE = 24
    NUM_WORKERS = 8
    torch.backends.cudnn.benchmark = True
    print("A100: Optimized batch size for EfficientViT 384px")
elif 'L4' in gpu_name:
    BATCH_SIZE = 16
    NUM_WORKERS = 6
    torch.backends.cudnn.benchmark = True
    print("L4: Balanced performance configuration for EfficientViT")
else:
    BATCH_SIZE = 12
    NUM_WORKERS = 4
    print("Default GPU: Conservative settings for EfficientViT")

# CASME II class mapping and analysis - preserved existing structure
CASME2_CLASSES = ['others', 'disgust', 'happiness', 'repression', 'surprise', 'sadness', 'fear']
CLASS_TO_IDX = {cls: idx for idx, cls in enumerate(CASME2_CLASSES)}

# Analyze class distribution from metadata
train_dist = casme2_metadata['train']['class_distribution']
val_dist = casme2_metadata['val']['class_distribution']
test_dist = casme2_metadata['test']['class_distribution']

print(f"\nTrain distribution: {train_dist}")
print(f"Validation distribution: {val_dist}")
print(f"Test distribution: {test_dist}")

# Apply optimized class weights based on loss function selection
if USE_FOCAL_LOSS:
    # For Focal Loss - use normalized alpha weights (per-class importance)
    class_weights = torch.tensor(FOCAL_LOSS_ALPHA_WEIGHTS, dtype=torch.float32).to(device)
    print(f"Applied Focal Loss alpha weights: {class_weights.cpu().numpy()}")
    print(f"Alpha weights sum: {class_weights.sum().item():.3f}")
else:
    # For CrossEntropy - use inverse sqrt frequency weights
    class_weights = torch.tensor(CROSSENTROPY_CLASS_WEIGHTS, dtype=torch.float32).to(device)
    print(f"Applied CrossEntropy class weights: {class_weights.cpu().numpy()}")

# CASME II EfficientViT Optimized Configuration
CASME2_EFFICIENTVIT_CONFIG = {
    # Architecture configuration - EfficientViT specific
    'efficientvit_model': EFFICIENTVIT_MODEL_NAME,
    'efficientvit_variant': EFFICIENTVIT_MODEL_VARIANT,
    'embed_dims': EXPECTED_EMBED_DIMS,
    'final_embed_dim': EXPECTED_FINAL_DIM,
    'input_size': 224,  # Native EfficientViT resolution
    'num_classes': 7,
    'dropout_rate': 0.2,
    'expected_params': EXPECTED_PARAMS,

    # Training configuration (proven effective from medical imaging)
    'learning_rate': 1e-5,
    'weight_decay': 1e-5,
    'gradient_clip': 1.0,
    'num_epochs': 50,
    'batch_size': BATCH_SIZE,
    'num_workers': NUM_WORKERS,
    'device': device,

    # Scheduler configuration
    'scheduler_type': 'plateau',
    'scheduler_mode': 'max',
    'scheduler_factor': 0.5,
    'scheduler_patience': 3,
    'scheduler_min_lr': 1e-6,
    'scheduler_monitor': 'val_f1_macro',

    # Optimized loss configuration
    'use_focal_loss': USE_FOCAL_LOSS,
    'focal_loss_gamma': FOCAL_LOSS_GAMMA,
    'focal_loss_alpha_weights': FOCAL_LOSS_ALPHA_WEIGHTS,
    'crossentropy_class_weights': CROSSENTROPY_CLASS_WEIGHTS,
    'class_weights': class_weights,

    # Evaluation configuration
    'use_macro_avg': True,
    'early_stopping': False,
    'save_best_f1': True,
    'save_strategy': 'best_only'
}

print(f"\nEfficientViT Configuration Summary:")
print(f"  Model: {CASME2_EFFICIENTVIT_CONFIG['efficientvit_model']}")
print(f"  Variant: {CASME2_EFFICIENTVIT_CONFIG['efficientvit_variant'].upper()}")
print(f"  Input size: {CASME2_EFFICIENTVIT_CONFIG['input_size']}px")
print(f"  Cascaded Group Attention: Enabled")
print(f"  Learning rate: {CASME2_EFFICIENTVIT_CONFIG['learning_rate']}")
print(f"  Batch size: {BATCH_SIZE}")

# =====================================================
# ADVANCED FOCAL LOSS IMPLEMENTATION - Per-Class Alpha Support (Preserved)
# =====================================================

class OptimizedFocalLoss(nn.Module):
    """
    Advanced Focal Loss implementation with per-class alpha support
    Paper: "Focal Loss for Dense Object Detection" (Lin et al., 2017)

    Enhanced Formula: FL(p_t) = -α_t(1-p_t)^γ log(p_t)

    Args:
        alpha (list/tensor): Per-class alpha weights (must sum to 1.0)
        gamma (float): Focusing parameter for hard examples (default: 2.0)
        reduction (str): Reduction method ('mean', 'sum', 'none')
    """

    def __init__(self, alpha=None, gamma=2.0, reduction='mean'):
        super(OptimizedFocalLoss, self).__init__()

        if alpha is not None:
            if isinstance(alpha, list):
                self.alpha = torch.tensor(alpha, dtype=torch.float32)
            else:
                self.alpha = alpha

            # Validation: alpha should sum to 1.0 for proper normalization
            alpha_sum = self.alpha.sum().item()
            if abs(alpha_sum - 1.0) > 0.01:
                print(f"Warning: Alpha weights sum to {alpha_sum:.3f}, expected 1.0")

        else:
            self.alpha = None

        self.gamma = gamma
        self.reduction = reduction

    def forward(self, inputs, targets):
        # Calculate cross entropy loss
        ce_loss = F.cross_entropy(inputs, targets, reduction='none')

        # Calculate p_t (probability of true class)
        pt = torch.exp(-ce_loss)

        # Apply per-class alpha if provided
        if self.alpha is not None:
            if self.alpha.device != targets.device:
                self.alpha = self.alpha.to(targets.device)
            alpha_t = self.alpha.gather(0, targets)
        else:
            alpha_t = 1.0

        # Apply focal loss formula: α_t(1-p_t)^γ * CE_loss
        focal_loss = alpha_t * (1 - pt) ** self.gamma * ce_loss

        # Apply reduction
        if self.reduction == 'mean':
            return focal_loss.mean()
        elif self.reduction == 'sum':
            return focal_loss.sum()
        else:
            return focal_loss

# EfficientViT Architecture for CASME II - Fixed TIMM Integration
class EfficientViTCASME2Baseline(nn.Module):
    """EfficientViT baseline for CASME II micro-expression recognition with proper TIMM integration"""

    def __init__(self, num_classes, dropout_rate=0.2):
        super(EfficientViTCASME2Baseline, self).__init__()

        # CRITICAL FIX: Load TIMM EfficientViT with original classification head first
        print("Loading TIMM EfficientViT with original head...")
        self.efficientvit = timm.create_model(
            CASME2_EFFICIENTVIT_CONFIG['efficientvit_model'],
            pretrained=True,
            num_classes=1000  # Keep original ImageNet head initially
        )

        # Enable fine-tuning for all parameters
        for param in self.efficientvit.parameters():
            param.requires_grad = True

        # Get feature extractor (remove only the final classifier)
        if hasattr(self.efficientvit, 'head'):
            # EfficientViT has 'head' attribute
            if hasattr(self.efficientvit.head, 'fc') or hasattr(self.efficientvit.head, 'linear'):
                # Get dimension from the classifier input
                if hasattr(self.efficientvit.head, 'fc'):
                    self.efficientvit_feature_dim = self.efficientvit.head.fc.in_features
                    self.efficientvit.head.fc = nn.Identity()  # Remove final layer
                elif hasattr(self.efficientvit.head, 'linear'):
                    self.efficientvit_feature_dim = self.efficientvit.head.linear.in_features
                    self.efficientvit.head.linear = nn.Identity()  # Remove final layer
            else:
                # Head is a simple Linear layer
                self.efficientvit_feature_dim = self.efficientvit.head.in_features
                self.efficientvit.head = nn.Identity()
        elif hasattr(self.efficientvit, 'classifier'):
            # Alternative: classifier attribute
            self.efficientvit_feature_dim = self.efficientvit.classifier.in_features
            self.efficientvit.classifier = nn.Identity()
        else:
            # Fallback: use expected dimension
            print("Warning: Could not determine feature dimension, using expected value")
            self.efficientvit_feature_dim = CASME2_EFFICIENTVIT_CONFIG['final_embed_dim']

        print(f"EfficientViT feature dimension (extracted): {self.efficientvit_feature_dim}")
        print(f"Expected embed dimensions: {CASME2_EFFICIENTVIT_CONFIG['embed_dims']}")

        # Verify feature dimension is reasonable
        if self.efficientvit_feature_dim < 100 or self.efficientvit_feature_dim > 2048:
            print(f"Warning: Unusual feature dimension {self.efficientvit_feature_dim}, using fallback")
            self.efficientvit_feature_dim = CASME2_EFFICIENTVIT_CONFIG['final_embed_dim']

        # Custom classification head with proper dimensions
        self.classifier_layers = nn.Sequential(
            nn.Linear(self.efficientvit_feature_dim, 512),
            nn.LayerNorm(512),
            nn.GELU(),
            nn.Dropout(dropout_rate),

            nn.Linear(512, 128),
            nn.LayerNorm(128),
            nn.GELU(),
            nn.Dropout(dropout_rate),
        )

        # Final classification layer for CASME II classes
        self.classifier = nn.Linear(128, num_classes)

        print(f"EfficientViT CASME II: {self.efficientvit_feature_dim} -> CGA -> 512 -> 128 -> {num_classes}")

        # Count total parameters for verification
        total_params = sum(p.numel() for p in self.parameters())
        trainable_params = sum(p.numel() for p in self.parameters() if p.requires_grad)
        print(f"Model parameters: Total={total_params/1e6:.1f}M, Trainable={trainable_params/1e6:.1f}M")

    def forward(self, x):
        # EfficientViT forward pass with proper feature extraction
        # Input shape: [batch_size, 3, 224, 224]
        features = self.efficientvit(x)

        # Features should now be properly extracted
        # Shape: [batch_size, feature_dim]

        # Classification pipeline
        processed_features = self.classifier_layers(features)
        output = self.classifier(processed_features)

        return output

# Enhanced optimizer and scheduler factory
def create_optimizer_scheduler_casme2(model, config):
    """Create optimizer and scheduler for CASME II EfficientViT training"""

    # AdamW optimizer with proven configuration
    optimizer = optim.AdamW(
        model.parameters(),
        lr=config['learning_rate'],
        weight_decay=config['weight_decay'],
        betas=(0.9, 0.999)
    )

    # ReduceLROnPlateau scheduler monitoring validation F1
    if config['scheduler_type'] == 'plateau':
        scheduler = optim.lr_scheduler.ReduceLROnPlateau(
            optimizer,
            mode=config['scheduler_mode'],
            factor=config['scheduler_factor'],
            patience=config['scheduler_patience'],
            min_lr=config['scheduler_min_lr']
        )
        print(f"Scheduler: ReduceLROnPlateau monitoring {config['scheduler_monitor']}")
    else:
        scheduler = None

    return optimizer, scheduler

# EfficientViT Image Transforms setup for 384px input
print("\nSetting up EfficientViT transforms for 384px input...")

# Get TIMM data config for EfficientViT
efficientvit_model_temp = timm.create_model(CASME2_EFFICIENTVIT_CONFIG['efficientvit_model'], pretrained=False)
data_config = timm.data.resolve_model_data_config(efficientvit_model_temp)
# Use native resolution (224px) - do not override to 384px

# Training transforms with data augmentation
efficientvit_transform_train = timm.data.create_transform(
    **data_config,
    is_training=True,
    auto_augment=None  # Disable auto augment for micro-expressions
)

# Validation transforms without augmentation
efficientvit_transform_val = timm.data.create_transform(
    **data_config,
    is_training=False
)

print(f"EfficientViT transforms configured for native 224px with cascaded group attention processing")
print(f"Data config: {data_config}")

# Transform wrapper functions
def efficientvit_transform_train_wrapper(image):
    """Training transform wrapper for EfficientViT"""
    return efficientvit_transform_train(image)

def efficientvit_transform_val_wrapper(image):
    """Validation transform wrapper for EfficientViT"""
    return efficientvit_transform_val(image)

# Custom Dataset class for CASME II - preserved existing structure
class CASME2Dataset(Dataset):
    """Custom dataset class for CASME II with JSON metadata support"""

    def __init__(self, split_metadata, dataset_root, transform=None, split='train'):
        self.metadata = split_metadata[split]['samples']
        self.dataset_root = dataset_root
        self.transform = transform
        self.split = split

        print(f"Loaded {len(self.metadata)} samples for {split} split")

    def __len__(self):
        return len(self.metadata)

    def __getitem__(self, idx):
        sample = self.metadata[idx]

        # Load image
        image_path = os.path.join(self.dataset_root, self.split, sample['image_filename'])
        image = Image.open(image_path).convert('RGB')

        # Apply transform (will resize to native EfficientViT resolution)
        if self.transform:
            image = self.transform(image)

        # Get class label
        emotion = sample['emotion']
        label = CLASS_TO_IDX[emotion]

        return image, label, sample['sample_id']

# Create directories - updated for EfficientViT
os.makedirs(CHECKPOINT_ROOT, exist_ok=True)
os.makedirs(f"{RESULTS_ROOT}/training_logs", exist_ok=True)
os.makedirs(f"{RESULTS_ROOT}/evaluation_results", exist_ok=True)

# Dataset paths - preserved existing structure
TRAIN_PATH = f"{DATASET_ROOT}/train"
VAL_PATH = f"{DATASET_ROOT}/val"
TEST_PATH = f"{DATASET_ROOT}/test"

print(f"\nDataset paths:")
print(f"Train: {TRAIN_PATH}")
print(f"Validation: {VAL_PATH}")
print(f"Test: {TEST_PATH}")

# Enhanced architecture validation with cascaded attention calculation
print("\nEfficientViT CASME II architecture validation...")

try:
    test_model = EfficientViTCASME2Baseline(num_classes=7, dropout_rate=0.2).to(device)
    test_input = torch.randn(1, 3, 224, 224).to(device)  # Native EfficientViT resolution
    test_output = test_model(test_input)

    # Calculate model parameters
    total_params = sum(p.numel() for p in test_model.parameters())
    trainable_params = sum(p.numel() for p in test_model.parameters() if p.requires_grad)

    print(f"Validation successful: Output shape {test_output.shape}")
    print(f"Total parameters: {total_params/1e6:.1f}M")
    print(f"Trainable parameters: {trainable_params/1e6:.1f}M")
    print(f"Expected parameters: {CASME2_EFFICIENTVIT_CONFIG['expected_params']}M")
    print(f"Cascaded Group Attention: Active")

    del test_model, test_input, test_output
    torch.cuda.empty_cache()

except Exception as e:
    print(f"Validation failed: {e}")

# Optimized loss function factory with advanced configuration (preserved)
def create_criterion_casme2(weights, use_focal_loss=False, alpha_weights=None, gamma=2.0):
    """
    Optimized factory function to create loss criterion based on advanced configuration

    Args:
        weights (Tensor): Class weights for CrossEntropy (ignored if focal loss used)
        use_focal_loss (bool): Whether to use Focal Loss or CrossEntropy
        alpha_weights (list): Per-class alpha weights for Focal Loss (must sum to 1.0)
        gamma (float): Focal loss gamma parameter

    Returns:
        Loss function (nn.Module)
    """
    if use_focal_loss:
        print(f"Using Optimized Focal Loss with gamma={gamma}")
        if alpha_weights:
            print(f"Per-class alpha weights: {alpha_weights}")
            print(f"Alpha sum: {sum(alpha_weights):.3f}")
        return OptimizedFocalLoss(alpha=alpha_weights, gamma=gamma)
    else:
        print(f"Using CrossEntropy Loss with optimized class weights")
        print(f"Class weights: {weights.cpu().numpy()}")
        return nn.CrossEntropyLoss(weight=weights)

# Global configuration for training pipeline - enhanced for EfficientViT
GLOBAL_CONFIG_CASME2 = {
    'device': device,
    'batch_size': BATCH_SIZE,
    'num_workers': NUM_WORKERS,
    'num_classes': 7,
    'class_weights': class_weights,
    'class_names': CASME2_CLASSES,
    'class_to_idx': CLASS_TO_IDX,
    'transform_train': efficientvit_transform_train_wrapper,
    'transform_val': efficientvit_transform_val_wrapper,
    'efficientvit_config': CASME2_EFFICIENTVIT_CONFIG,
    'checkpoint_root': CHECKPOINT_ROOT,
    'results_root': RESULTS_ROOT,
    'train_path': TRAIN_PATH,
    'val_path': VAL_PATH,
    'test_path': TEST_PATH,
    'metadata': casme2_metadata,
    'optimizer_scheduler_factory': create_optimizer_scheduler_casme2,
    'criterion_factory': create_criterion_casme2
}

# Configuration validation and summary
print("\n" + "=" * 60)
print("CASME II EFFICIENTVIT OPTIMIZED BASELINE CONFIGURATION COMPLETE")
print("=" * 60)

print(f"Loss Configuration:")
if USE_FOCAL_LOSS:
    print(f"  Function: Optimized Focal Loss")
    print(f"  Gamma: {FOCAL_LOSS_GAMMA}")
    print(f"  Per-class Alpha: {FOCAL_LOSS_ALPHA_WEIGHTS}")
    print(f"  Alpha Sum: {sum(FOCAL_LOSS_ALPHA_WEIGHTS):.3f}")
else:
    print(f"  Function: CrossEntropy with Optimized Weights")
    print(f"  Class Weights: {CROSSENTROPY_CLASS_WEIGHTS}")

print(f"\nModel Configuration:")
print(f"  Architecture: {EFFICIENTVIT_MODEL_NAME}")
print(f"  Variant: EfficientViT-{EFFICIENTVIT_MODEL_VARIANT.upper()}")
print(f"  Embed Progression: {EXPECTED_EMBED_DIMS}")
print(f"  Final Dimension: {EXPECTED_FINAL_DIM}")
print(f"  Input Resolution: 224px (Native)")  # Updated to reflect native resolution
print(f"  Expected Parameters: {EXPECTED_PARAMS}M")

print(f"\nDataset Configuration:")
print(f"  Classes: {len(CASME2_CLASSES)}")
print(f"  Weight Optimization: {'Per-class Alpha' if USE_FOCAL_LOSS else 'Inverse Sqrt Frequency'}")
print(f"  Cascaded Group Attention: Memory efficient multi-head processing")

print("\nNext: Cell 2 - Dataset Loading and EfficientViT Training Pipeline")
# Out:
# ============================================================
# CASME II EFFICIENTVIT OPTIMIZED BASELINE INFRASTRUCTURE
# ============================================================
#
# [1] Mounting Google Drive...
# Mounted at /content/drive
# Google Drive mounted successfully
#
# [2] Importing required libraries...
# CASME II EfficientViT Optimized Baseline - Infrastructure Configuration
# ======================================================================
# Loading CASME II dataset metadata...
# Dataset: CASME2
# Total samples: 255
# Split strategy: stratified_80_10_10
# Using EfficientViT-M5 for optimized efficiency micro-expression recognition
#
# ==================================================
# OPTIMIZED EXPERIMENT CONFIGURATION
# ==================================================
# Loss Function: Focal Loss
#   Gamma: 2.0
#   Alpha Weights (per-class): [0.053, 0.067, 0.094, 0.102, 0.106, 0.201, 0.376]
#   Alpha Sum Validation: 0.999
# EfficientViT Model: efficientvit_m5.r224_in1k
# Variant: M5
# Embed Dimensions: [192, 288, 384]
# Final Dimension: 384
# Expected Parameters: 12.5M
# ==================================================
#
# Device: cuda
# GPU: NVIDIA L4 (23.8 GB)
# L4: Balanced performance configuration for EfficientViT
#
# Train distribution: {'others': 79, 'disgust': 50, 'happiness': 25, 'repression': 21, 'surprise': 20, 'sadness': 5, 'fear': 1}
# Validation distribution: {'others': 10, 'disgust': 6, 'happiness': 3, 'repression': 3, 'surprise': 2, 'sadness': 1, 'fear': 1}
# Test distribution: {'others': 10, 'disgust': 7, 'happiness': 4, 'repression': 3, 'surprise': 3, 'sadness': 1}
# Applied Focal Loss alpha weights: [0.053 0.067 0.094 0.102 0.106 0.201 0.376]
# Alpha weights sum: 0.999
#
# EfficientViT Configuration Summary:
#   Model: efficientvit_m5.r224_in1k
#   Variant: M5
#   Input size: 224px
#   Cascaded Group Attention: Enabled
#   Learning rate: 1e-05
#   Batch size: 16
#
# Setting up EfficientViT transforms for 384px input...
# EfficientViT transforms configured for native 224px with cascaded group attention processing
# Data config: {'input_size': (3, 224, 224), 'interpolation': 'bicubic', 'mean': (0.485, 0.456, 0.406), 'std': (0.229, 0.224, 0.225), 'crop_pct': 0.875, 'crop_mode': 'center'}
#
# Dataset paths:
# Train: /content/drive/MyDrive/RESEARCH-WORKSPACE/ACTIVE-PROJECTS/Thesis_MER_Project/datasets/processed_casme2/data_split/train
# Validation: /content/drive/MyDrive/RESEARCH-WORKSPACE/ACTIVE-PROJECTS/Thesis_MER_Project/datasets/processed_casme2/data_split/val
# Test: /content/drive/MyDrive/RESEARCH-WORKSPACE/ACTIVE-PROJECTS/Thesis_MER_Project/datasets/processed_casme2/data_split/test
#
# EfficientViT CASME II architecture validation...
# Loading TIMM EfficientViT with original head...
# model.safetensors:   0%|          | 0.00/50.3M [00:00<?, ?B/s]
# EfficientViT feature dimension (extracted): 384
# Expected embed dimensions: [192, 288, 384]
# EfficientViT CASME II: 384 -> CGA -> 512 -> 128 -> 7
# Model parameters: Total=12.4M, Trainable=12.4M
# Validation failed: Expected more than 1 value per channel when training, got input size torch.Size([1, 384])
#
# ============================================================
# CASME II EFFICIENTVIT OPTIMIZED BASELINE CONFIGURATION COMPLETE
# ============================================================
# Loss Configuration:
#   Function: Optimized Focal Loss
#   Gamma: 2.0
#   Per-class Alpha: [0.053, 0.067, 0.094, 0.102, 0.106, 0.201, 0.376]
#   Alpha Sum: 0.999
#
# Model Configuration:
#   Architecture: efficientvit_m5.r224_in1k
#   Variant: EfficientViT-M5
#   Embed Progression: [192, 288, 384]
#   Final Dimension: 384
#   Input Resolution: 224px (Native)
#   Expected Parameters: 12.5M
#
# Dataset Configuration:
#   Classes: 7
#   Weight Optimization: Per-class Alpha
#   Cascaded Group Attention: Memory efficient multi-head processing
#
# Next: Cell 2 - Dataset Loading and EfficientViT Training Pipeline

# %%
# @title Cell 2: CASME II EfficientViT Training Pipeline

# File: 02_03_EfficientViT_Direct_Enhanced_Baseline_Cell2.py
# Location: experiments/02_03_EfficientViT_Direct_Baseline.ipynb
# Purpose: Training pipeline for CASME II EfficientViT micro-expression recognition

import os
import time
import json
import numpy as np
from tqdm import tqdm
from sklearn.metrics import f1_score, precision_recall_fscore_support, accuracy_score
from concurrent.futures import ThreadPoolExecutor
import multiprocessing as mp

print("CASME II EfficientViT Enhanced Training Pipeline with Fixed Checkpoints")
print("=" * 70)
print(f"Loss Function: {'Optimized Focal Loss' if CASME2_EFFICIENTVIT_CONFIG['use_focal_loss'] else 'CrossEntropy Loss'}")
if CASME2_EFFICIENTVIT_CONFIG['use_focal_loss']:
    print(f"Focal Loss Parameters:")
    print(f"  Gamma: {CASME2_EFFICIENTVIT_CONFIG['focal_loss_gamma']}")
    print(f"  Per-class Alpha: {CASME2_EFFICIENTVIT_CONFIG['focal_loss_alpha_weights']}")
    print(f"  Alpha Sum: {sum(CASME2_EFFICIENTVIT_CONFIG['focal_loss_alpha_weights']):.3f}")
else:
    print(f"CrossEntropy Parameters:")
    print(f"  Optimized Class Weights: {CASME2_EFFICIENTVIT_CONFIG['crossentropy_class_weights']}")
print(f"EfficientViT Architecture: {CASME2_EFFICIENTVIT_CONFIG['efficientvit_variant'].upper()} variant")
print(f"Cascaded Group Attention: Memory efficient processing")
print(f"Training epochs: {CASME2_EFFICIENTVIT_CONFIG['num_epochs']}")
print(f"Scheduler patience: {CASME2_EFFICIENTVIT_CONFIG['scheduler_patience']}")

# Enhanced CASME II Dataset with optimized RAM caching for EfficientViT
class CASME2DatasetTrainingEfficientViT(Dataset):
    """Enhanced CASME II dataset for EfficientViT training with RAM caching optimization"""

    def __init__(self, split_metadata, dataset_root, transform=None, split='train', use_ram_cache=True):
        self.metadata = split_metadata[split]['samples']
        self.dataset_root = dataset_root
        self.transform = transform
        self.split = split
        self.use_ram_cache = use_ram_cache
        self.images = []
        self.labels = []
        self.sample_ids = []
        self.cached_images = []

        print(f"Loading CASME II {split} dataset for EfficientViT training...")

        # Process metadata
        for sample in self.metadata:
            image_path = os.path.join(dataset_root, split, sample['image_filename'])
            self.images.append(image_path)
            self.labels.append(CLASS_TO_IDX[sample['emotion']])
            self.sample_ids.append(sample['sample_id'])

        print(f"Loaded {len(self.images)} CASME II {split} samples")
        self._print_distribution()

        # RAM caching for training efficiency
        if self.use_ram_cache:
            self._preload_to_ram()

    def _print_distribution(self):
        """Print class distribution"""
        label_counts = {}
        for label in self.labels:
            label_counts[label] = label_counts.get(label, 0) + 1

        for label, count in sorted(label_counts.items()):
            class_name = CASME2_CLASSES[label]
            percentage = (count / len(self.labels)) * 100
            print(f"  {class_name}: {count} samples ({percentage:.1f}%)")

    def _preload_to_ram(self):
        """RAM preloading optimized for EfficientViT training"""
        print(f"Preloading {len(self.images)} {self.split} images to RAM for EfficientViT...")

        valid_images = 0
        self.cached_images = [None] * len(self.images)

        for i, img_path in enumerate(tqdm(self.images, desc=f"Loading {self.split}")):
            try:
                image = Image.open(img_path).convert('RGB')
                if image.size != (384, 384):
                    image = image.resize((384, 384), Image.Resampling.LANCZOS)
                self.cached_images[i] = image
                valid_images += 1
            except Exception as e:
                print(f"Error loading {img_path}: {e}")
                self.cached_images[i] = Image.new('RGB', (384, 384), (128, 128, 128))

        ram_usage_gb = len(self.cached_images) * 384 * 384 * 3 * 4 / 1e9
        print(f"{self.split.upper()} RAM caching completed: {valid_images} images, ~{ram_usage_gb:.2f}GB")

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        if self.use_ram_cache and self.cached_images[idx] is not None:
            image = self.cached_images[idx].copy()
        else:
            try:
                image = Image.open(self.images[idx]).convert('RGB')
                if image.size != (384, 384):
                    image = image.resize((384, 384), Image.Resampling.LANCZOS)
            except:
                image = Image.new('RGB', (384, 384), (128, 128, 128))

        if self.transform:
            image = self.transform(image)

        return image, self.labels[idx], self.sample_ids[idx]

# Enhanced metrics calculation with comprehensive error handling
def calculate_metrics_safe_robust(outputs, labels, class_names, average='macro'):
    """Calculate metrics with enhanced error handling and validation"""
    try:
        # Validate input tensors
        if outputs.size(0) != labels.size(0):
            raise ValueError(f"Batch size mismatch: outputs {outputs.size(0)} vs labels {labels.size(0)}")

        if isinstance(outputs, torch.Tensor):
            predictions = torch.argmax(outputs, dim=1).cpu().numpy()
        else:
            predictions = np.array(outputs)

        if isinstance(labels, torch.Tensor):
            labels = labels.cpu().numpy()
        else:
            labels = np.array(labels)

        # Validate predictions are in valid range
        unique_preds = np.unique(predictions)
        unique_labels = np.unique(labels)

        accuracy = accuracy_score(labels, predictions)
        precision, recall, f1, _ = precision_recall_fscore_support(
            labels, predictions,
            average=average,
            zero_division=0,
            labels=list(range(len(class_names)))
        )

        return {
            'accuracy': float(accuracy),
            'precision': float(precision),
            'recall': float(recall),
            'f1_score': float(f1)
        }
    except Exception as e:
        print(f"Warning: Enhanced metrics calculation error: {e}")
        return {
            'accuracy': 0.0,
            'precision': 0.0,
            'recall': 0.0,
            'f1_score': 0.0
        }

# Enhanced training epoch function with EfficientViT TIMM output validation
def train_epoch_efficientvit(model, dataloader, criterion, optimizer, device, epoch, total_epochs):
    """Enhanced training epoch for EfficientViT with TIMM model handling"""
    model.train()
    running_loss = 0.0
    all_outputs = []
    all_labels = []

    progress_bar = tqdm(dataloader, desc=f"CASME II EfficientViT Training Epoch {epoch+1}/{total_epochs}")

    for batch_idx, (images, labels, sample_ids) in enumerate(progress_bar):
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()

        # Enhanced EfficientViT model output validation - handle TIMM models
        try:
            outputs = model(images)
        except Exception as e:
            print(f"Error in EfficientViT forward pass: {e}")
            raise e

        # Robust output structure validation for EfficientViT
        if isinstance(outputs, (tuple, list)):
            outputs = outputs[0]
        elif isinstance(outputs, dict):
            # Handle potential EfficientViT-specific output dictionary
            outputs = outputs.get('logits', outputs.get('prediction', outputs))

        # Validate output shape for 7 CASME II classes
        if outputs.dim() != 2 or outputs.size(1) != 7:
            raise ValueError(f"Invalid CASME II EfficientViT output shape: {outputs.shape}, expected [batch_size, 7]")

        loss = criterion(outputs, labels)
        loss.backward()

        # Gradient clipping for EfficientViT stability
        torch.nn.utils.clip_grad_norm_(model.parameters(), CASME2_EFFICIENTVIT_CONFIG['gradient_clip'])

        optimizer.step()
        running_loss += loss.item()

        # Memory optimized: Move to CPU before accumulating
        all_outputs.append(outputs.detach().cpu())
        all_labels.append(labels.detach().cpu())

        # Update progress with EfficientViT-specific information
        if batch_idx % 5 == 0:
            avg_loss = running_loss / (batch_idx + 1)
            current_lr = optimizer.param_groups[0]['lr']
            progress_bar.set_postfix({
                'Loss': f'{avg_loss:.4f}',
                'LR': f'{current_lr:.2e}',
                'EffViT': CASME2_EFFICIENTVIT_CONFIG['efficientvit_variant']
            })

    # Enhanced metrics calculation with error recovery
    try:
        epoch_outputs = torch.cat(all_outputs, dim=0)
        epoch_labels = torch.cat(all_labels, dim=0)
        metrics = calculate_metrics_safe_robust(epoch_outputs, epoch_labels, CASME2_CLASSES, average='macro')
    except Exception as e:
        print(f"Warning: EfficientViT training metrics calculation failed: {e}")
        metrics = {'accuracy': 0.0, 'precision': 0.0, 'recall': 0.0, 'f1_score': 0.0}

    avg_loss = running_loss / len(dataloader)
    return avg_loss, metrics

# Enhanced validation epoch function with EfficientViT TIMM output validation
def validate_epoch_efficientvit(model, dataloader, criterion, device, epoch, total_epochs):
    """Enhanced validation epoch for EfficientViT with TIMM model handling"""
    model.eval()
    running_loss = 0.0
    all_outputs = []
    all_labels = []
    all_sample_ids = []

    with torch.no_grad():
        progress_bar = tqdm(dataloader, desc=f"CASME II EfficientViT Validation Epoch {epoch+1}/{total_epochs}")

        for batch_idx, (images, labels, sample_ids) in enumerate(progress_bar):
            images, labels = images.to(device), labels.to(device)

            # Enhanced EfficientViT model output validation - handle TIMM models
            try:
                outputs = model(images)
            except Exception as e:
                print(f"Error in EfficientViT forward pass: {e}")
                raise e

            # Robust output structure validation for EfficientViT
            if isinstance(outputs, (tuple, list)):
                outputs = outputs[0]
            elif isinstance(outputs, dict):
                outputs = outputs.get('logits', outputs.get('prediction', outputs))

            loss = criterion(outputs, labels)
            running_loss += loss.item()

            # Memory optimized: Move to CPU before accumulating
            all_outputs.append(outputs.detach().cpu())
            all_labels.append(labels.detach().cpu())
            all_sample_ids.extend(sample_ids)

            if batch_idx % 3 == 0:
                avg_loss = running_loss / (batch_idx + 1)
                progress_bar.set_postfix({
                    'Val Loss': f'{avg_loss:.4f}',
                    'EffViT': CASME2_EFFICIENTVIT_CONFIG['efficientvit_variant']
                })

    # Enhanced metrics calculation with error recovery
    try:
        epoch_outputs = torch.cat(all_outputs, dim=0)
        epoch_labels = torch.cat(all_labels, dim=0)
        metrics = calculate_metrics_safe_robust(epoch_outputs, epoch_labels, CASME2_CLASSES, average='macro')
    except Exception as e:
        print(f"Warning: EfficientViT validation metrics calculation failed: {e}")
        metrics = {'accuracy': 0.0, 'precision': 0.0, 'recall': 0.0, 'f1_score': 0.0}

    avg_loss = running_loss / len(dataloader)
    return avg_loss, metrics, all_sample_ids

# FIXED: Enhanced checkpoint saving function with complete device migration
def save_checkpoint_robust_fixed(model, optimizer, scheduler, epoch, train_metrics, val_metrics,
                                checkpoint_dir, best_metrics, config, max_retries=3):
    """FIXED: Enhanced checkpoint saving with complete device migration and error recovery"""

    print(f"Saving EfficientViT checkpoint with enhanced device migration...")

    # CRITICAL FIX: Complete device migration to CPU before serialization
    try:
        # 1. Move model state dict to CPU with proper tensor handling
        print("  Migrating EfficientViT model state dict to CPU...")
        model_state_cpu = {}
        for k, v in model.state_dict().items():
            if isinstance(v, torch.Tensor):
                model_state_cpu[k] = v.cpu().clone()
            else:
                model_state_cpu[k] = v

        # 2. Move optimizer state dict to CPU with nested tensor handling
        print("  Migrating optimizer state dict to CPU...")
        optimizer_state_cpu = {}
        for k, v in optimizer.state_dict().items():
            if isinstance(v, torch.Tensor):
                optimizer_state_cpu[k] = v.cpu().clone()
            elif isinstance(v, dict):
                # Handle nested dictionaries in optimizer state
                optimizer_state_cpu[k] = {}
                for nested_k, nested_v in v.items():
                    if isinstance(nested_v, torch.Tensor):
                        optimizer_state_cpu[k][nested_k] = nested_v.cpu().clone()
                    elif isinstance(nested_v, dict):
                        # Handle double-nested dictionaries (param_groups, etc.)
                        optimizer_state_cpu[k][nested_k] = {}
                        for deep_k, deep_v in nested_v.items():
                            if isinstance(deep_v, torch.Tensor):
                                optimizer_state_cpu[k][nested_k][deep_k] = deep_v.cpu().clone()
                            else:
                                optimizer_state_cpu[k][nested_k][deep_k] = deep_v
                    else:
                        optimizer_state_cpu[k][nested_k] = nested_v
            else:
                optimizer_state_cpu[k] = v

        # 3. Move scheduler state dict to CPU if exists
        scheduler_state_cpu = None
        if scheduler:
            print("  Migrating scheduler state dict to CPU...")
            scheduler_state_cpu = {}
            for k, v in scheduler.state_dict().items():
                if isinstance(v, torch.Tensor):
                    scheduler_state_cpu[k] = v.cpu().clone()
                else:
                    scheduler_state_cpu[k] = v

        # 4. Force GPU memory cleanup before serialization
        if torch.cuda.is_available():
            torch.cuda.empty_cache()
            torch.cuda.synchronize()

        print("  Device migration completed successfully")

    except Exception as e:
        print(f"ERROR: Device migration failed: {e}")
        return None

    # Convert all metrics to serializable format
    def make_serializable_enhanced(obj):
        """Enhanced serialization with complete tensor handling"""
        if isinstance(obj, torch.Tensor):
            return obj.cpu().item() if obj.numel() == 1 else obj.cpu().tolist()
        elif isinstance(obj, np.ndarray):
            return obj.tolist()
        elif isinstance(obj, (np.integer, np.int32, np.int64)):
            return int(obj)
        elif isinstance(obj, (np.floating, np.float32, np.float64)):
            return float(obj)
        elif isinstance(obj, dict):
            return {k: make_serializable_enhanced(v) for k, v in obj.items()}
        elif isinstance(obj, (list, tuple)):
            return [make_serializable_enhanced(item) for item in obj]
        else:
            try:
                return float(obj) if isinstance(obj, (int, float)) else str(obj)
            except:
                return str(obj)

    # Create checkpoint with CPU-migrated state dicts
    checkpoint = {
        'epoch': epoch,
        'model_state_dict': model_state_cpu,  # Now on CPU
        'optimizer_state_dict': optimizer_state_cpu,  # Now on CPU
        'scheduler_state_dict': scheduler_state_cpu,  # Now on CPU or None
        'train_metrics': make_serializable_enhanced(train_metrics),
        'val_metrics': make_serializable_enhanced(val_metrics),
        'casme2_efficientvit_config': make_serializable_enhanced(config),
        'best_f1': float(best_metrics['f1']),
        'best_loss': float(best_metrics['loss']),
        'best_acc': float(best_metrics['accuracy']),
        'class_names': CASME2_CLASSES,
        'num_classes': 7,
        'efficientvit_variant': config['efficientvit_variant'],
        'efficientvit_model': config['efficientvit_model']
    }

    best_path = f"{checkpoint_dir}/casme2_efficientvit_direct_best_f1.pth"

    # Enhanced save with retry logic and proper file handling
    for attempt in range(max_retries):
        try:
            # Create temporary file first
            temp_path = f"{best_path}.tmp"

            print(f"  Attempt {attempt + 1}: Saving to temporary file...")
            torch.save(checkpoint, temp_path)

            # Move temporary file to final location (atomic operation)
            import shutil
            shutil.move(temp_path, best_path)

            print(f"EfficientViT checkpoint saved successfully: {os.path.basename(best_path)}")
            print(f"  EfficientViT variant: {config['efficientvit_variant']}")
            print(f"  Model: {config['efficientvit_model']}")
            return best_path

        except Exception as e:
            print(f"EfficientViT checkpoint save attempt {attempt + 1} failed: {e}")

            # Clean up temporary file if it exists
            if os.path.exists(temp_path):
                try:
                    os.remove(temp_path)
                except:
                    pass

            if attempt < max_retries - 1:
                print(f"  Retrying in 2 seconds...")
                time.sleep(2)  # Brief pause before retry

                # Additional memory cleanup before retry
                if torch.cuda.is_available():
                    torch.cuda.empty_cache()
                    torch.cuda.synchronize()
                continue
            else:
                print(f"All {max_retries} EfficientViT checkpoint save attempts failed")
                return None

    return None

# Safe JSON serialization function - enhanced for EfficientViT
def safe_json_serialize_efficientvit(obj):
    """Convert objects to JSON-serializable format with EfficientViT-specific handling"""
    if isinstance(obj, torch.Tensor):
        return obj.cpu().item() if obj.numel() == 1 else obj.cpu().numpy().tolist()
    elif isinstance(obj, np.ndarray):
        return obj.tolist()
    elif isinstance(obj, (np.integer, np.int32, np.int64)):
        return int(obj)
    elif isinstance(obj, (np.floating, np.float32, np.float64)):
        return float(obj)
    elif isinstance(obj, dict):
        return {k: safe_json_serialize_efficientvit(v) for k, v in obj.items()}
    elif isinstance(obj, (list, tuple)):
        return [safe_json_serialize_efficientvit(item) for item in obj]
    elif hasattr(obj, '__dict__'):
        return safe_json_serialize_efficientvit(obj.__dict__)
    else:
        try:
            return float(obj) if isinstance(obj, (int, float)) else str(obj)
        except:
            return str(obj)

# Create enhanced datasets for EfficientViT
print("\nCreating CASME II EfficientViT training datasets...")

train_dataset = CASME2DatasetTrainingEfficientViT(
    split_metadata=GLOBAL_CONFIG_CASME2['metadata'],
    dataset_root=GLOBAL_CONFIG_CASME2['train_path'].replace('/train', ''),
    transform=GLOBAL_CONFIG_CASME2['transform_train'],
    split='train',
    use_ram_cache=True
)

val_dataset = CASME2DatasetTrainingEfficientViT(
    split_metadata=GLOBAL_CONFIG_CASME2['metadata'],
    dataset_root=GLOBAL_CONFIG_CASME2['val_path'].replace('/val', ''),
    transform=GLOBAL_CONFIG_CASME2['transform_val'],
    split='val',
    use_ram_cache=True
)

# Create data loaders with EfficientViT-optimized settings
train_loader = DataLoader(
    train_dataset,
    batch_size=CASME2_EFFICIENTVIT_CONFIG['batch_size'],
    shuffle=True,
    num_workers=CASME2_EFFICIENTVIT_CONFIG['num_workers'],
    pin_memory=True,
    prefetch_factor=2
)

val_loader = DataLoader(
    val_dataset,
    batch_size=CASME2_EFFICIENTVIT_CONFIG['batch_size'],
    shuffle=False,
    num_workers=CASME2_EFFICIENTVIT_CONFIG['num_workers'],
    pin_memory=True,
    prefetch_factor=2
)

print(f"Training batches: {len(train_loader)} (samples: {len(train_dataset)})")
print(f"Validation batches: {len(val_loader)} (samples: {len(val_dataset)})")

# Initialize EfficientViT model, criterion, optimizer, scheduler
print("\nInitializing CASME II EfficientViT enhanced model...")
model = EfficientViTCASME2Baseline(
    num_classes=GLOBAL_CONFIG_CASME2['num_classes'],
    dropout_rate=CASME2_EFFICIENTVIT_CONFIG['dropout_rate']
).to(GLOBAL_CONFIG_CASME2['device'])

# Enhanced criterion creation using configurable factory function
if CASME2_EFFICIENTVIT_CONFIG['use_focal_loss']:
    criterion = GLOBAL_CONFIG_CASME2['criterion_factory'](
        weights=GLOBAL_CONFIG_CASME2['class_weights'],
        use_focal_loss=True,
        alpha_weights=CASME2_EFFICIENTVIT_CONFIG['focal_loss_alpha_weights'],
        gamma=CASME2_EFFICIENTVIT_CONFIG['focal_loss_gamma']
    )
else:
    criterion = GLOBAL_CONFIG_CASME2['criterion_factory'](
        weights=GLOBAL_CONFIG_CASME2['class_weights'],
        use_focal_loss=False,
        alpha_weights=None,
        gamma=2.0
    )

optimizer, scheduler = GLOBAL_CONFIG_CASME2['optimizer_scheduler_factory'](
    model, CASME2_EFFICIENTVIT_CONFIG
)

print(f"Optimizer: AdamW (LR={CASME2_EFFICIENTVIT_CONFIG['learning_rate']})")
print(f"Scheduler: ReduceLROnPlateau (patience={CASME2_EFFICIENTVIT_CONFIG['scheduler_patience']})")
print(f"Criterion: {'Optimized Focal Loss' if CASME2_EFFICIENTVIT_CONFIG['use_focal_loss'] else 'CrossEntropy'}")
print(f"EfficientViT Architecture: {CASME2_EFFICIENTVIT_CONFIG['efficientvit_variant'].upper()} variant")

# Training history tracking for EfficientViT
training_history = {
    'train_loss': [],
    'val_loss': [],
    'train_f1': [],
    'val_f1': [],
    'train_acc': [],
    'val_acc': [],
    'learning_rate': [],
    'epoch_time': []
}

# Enhanced best metrics tracking for multi-criteria checkpoint saving
best_metrics = {
    'f1': 0.0,
    'loss': float('inf'),
    'accuracy': 0.0,
    'epoch': 0
}

print("\nStarting CASME II EfficientViT enhanced training with fixed checkpoints...")
print(f"Training configuration: {CASME2_EFFICIENTVIT_CONFIG['num_epochs']} epochs")
print(f"Cascaded Group Attention: Memory efficient multi-head processing")
print("=" * 70)

# Main training loop with enhanced checkpoint reliability for EfficientViT
start_time = time.time()

for epoch in range(CASME2_EFFICIENTVIT_CONFIG['num_epochs']):
    epoch_start_time = time.time()
    print(f"\nEpoch {epoch+1}/{CASME2_EFFICIENTVIT_CONFIG['num_epochs']}")

    # Training phase with EfficientViT-specific adaptations
    train_loss, train_metrics = train_epoch_efficientvit(
        model, train_loader, criterion, optimizer,
        GLOBAL_CONFIG_CASME2['device'], epoch, CASME2_EFFICIENTVIT_CONFIG['num_epochs']
    )

    # Validation phase with EfficientViT-specific adaptations
    val_loss, val_metrics, val_sample_ids = validate_epoch_efficientvit(
        model, val_loader, criterion,
        GLOBAL_CONFIG_CASME2['device'], epoch, CASME2_EFFICIENTVIT_CONFIG['num_epochs']
    )

    # Update scheduler
    if scheduler:
        scheduler.step(val_metrics['f1_score'])

    # Record training history
    epoch_time = time.time() - epoch_start_time
    current_lr = optimizer.param_groups[0]['lr']

    training_history['train_loss'].append(float(train_loss))
    training_history['val_loss'].append(float(val_loss))
    training_history['train_f1'].append(float(train_metrics['f1_score']))
    training_history['val_f1'].append(float(val_metrics['f1_score']))
    training_history['train_acc'].append(float(train_metrics['accuracy']))
    training_history['val_acc'].append(float(val_metrics['accuracy']))
    training_history['learning_rate'].append(float(current_lr))
    training_history['epoch_time'].append(float(epoch_time))

    # Print epoch summary
    print(f"Train - Loss: {train_loss:.4f}, F1: {train_metrics['f1_score']:.4f}, Acc: {train_metrics['accuracy']:.4f}")
    print(f"Val   - Loss: {val_loss:.4f}, F1: {val_metrics['f1_score']:.4f}, Acc: {val_metrics['accuracy']:.4f}")
    print(f"Time  - Epoch: {epoch_time:.1f}s, LR: {current_lr:.2e}")

    # Enhanced multi-criteria checkpoint saving logic
    save_model = False
    improvement_reason = ""

    # Multi-criteria evaluation hierarchy
    if val_metrics['f1_score'] > best_metrics['f1']:
        save_model = True
        improvement_reason = "Higher F1"
    elif val_metrics['f1_score'] == best_metrics['f1']:
        if val_loss < best_metrics['loss']:
            save_model = True
            improvement_reason = "Same F1, Lower Loss"
        elif val_loss == best_metrics['loss'] and val_metrics['accuracy'] > best_metrics['accuracy']:
            save_model = True
            improvement_reason = "Same F1&Loss, Higher Accuracy"

    if save_model:
        best_metrics['f1'] = val_metrics['f1_score']
        best_metrics['loss'] = val_loss
        best_metrics['accuracy'] = val_metrics['accuracy']
        best_metrics['epoch'] = epoch + 1

        # Use FIXED checkpoint saving function
        best_model_path = save_checkpoint_robust_fixed(
            model, optimizer, scheduler, epoch,
            train_metrics, val_metrics, GLOBAL_CONFIG_CASME2['checkpoint_root'],
            best_metrics, CASME2_EFFICIENTVIT_CONFIG
        )

        if best_model_path:
            print(f"New best EfficientViT model: {improvement_reason} - F1: {best_metrics['f1']:.4f}")
        else:
            print(f"Warning: Failed to save EfficientViT checkpoint despite improvement")

    # Progress tracking
    elapsed_time = time.time() - start_time
    estimated_total = (elapsed_time / (epoch + 1)) * CASME2_EFFICIENTVIT_CONFIG['num_epochs']
    remaining_time = estimated_total - elapsed_time
    progress_pct = ((epoch + 1) / CASME2_EFFICIENTVIT_CONFIG['num_epochs']) * 100

    print(f"Progress: {progress_pct:.1f}% | Best F1: {best_metrics['f1']:.4f} | ETA: {remaining_time/60:.1f}min | EfficientViT-{CASME2_EFFICIENTVIT_CONFIG['efficientvit_variant'].upper()}")

# Training completion
total_time = time.time() - start_time
actual_epochs = CASME2_EFFICIENTVIT_CONFIG['num_epochs']

print("\n" + "=" * 70)
print("CASME II EFFICIENTVIT ENHANCED BASELINE TRAINING COMPLETED")
print("=" * 70)
print(f"Training time: {total_time/60:.1f} minutes")
print(f"Epochs completed: {actual_epochs}")
print(f"Best validation F1: {best_metrics['f1']:.4f} (epoch {best_metrics['epoch']})")
print(f"Final train F1: {training_history['train_f1'][-1]:.4f}")
print(f"Final validation F1: {training_history['val_f1'][-1]:.4f}")
print(f"EfficientViT Architecture: {CASME2_EFFICIENTVIT_CONFIG['efficientvit_variant'].upper()} variant")

# Enhanced training documentation export for EfficientViT
results_dir = GLOBAL_CONFIG_CASME2['results_root']
os.makedirs(f"{results_dir}/training_logs", exist_ok=True)

training_history_path = f"{results_dir}/training_logs/casme2_efficientvit_direct_training_history.json"

print("\nExporting enhanced EfficientViT training documentation...")

try:
    # Create comprehensive training summary with EfficientViT-specific configuration
    training_summary = {
        'experiment_type': 'CASME2_EfficientViT_Enhanced_Baseline',
        'experiment_configuration': {
            'loss_function': 'Optimized Focal Loss' if CASME2_EFFICIENTVIT_CONFIG['use_focal_loss'] else 'CrossEntropy',
            'weight_approach': 'Per-class Alpha (sum=1.0)' if CASME2_EFFICIENTVIT_CONFIG['use_focal_loss'] else 'Inverse Sqrt Frequency',
            'focal_loss_gamma': CASME2_EFFICIENTVIT_CONFIG['focal_loss_gamma'],
            'focal_loss_alpha_weights': CASME2_EFFICIENTVIT_CONFIG['focal_loss_alpha_weights'],
            'crossentropy_class_weights': CASME2_EFFICIENTVIT_CONFIG['crossentropy_class_weights'],
            'efficientvit_model': CASME2_EFFICIENTVIT_CONFIG['efficientvit_model'],
            'efficientvit_variant': CASME2_EFFICIENTVIT_CONFIG['efficientvit_variant'],
            'embed_dims': CASME2_EFFICIENTVIT_CONFIG['embed_dims'],
            'final_embed_dim': CASME2_EFFICIENTVIT_CONFIG['final_embed_dim']
        },
        'training_history': safe_json_serialize_efficientvit(training_history),
        'best_val_f1': float(best_metrics['f1']),
        'best_val_loss': float(best_metrics['loss']),
        'best_val_accuracy': float(best_metrics['accuracy']),
        'best_epoch': int(best_metrics['epoch']),
        'total_epochs': int(actual_epochs),
        'total_time_minutes': float(total_time / 60),
        'average_epoch_time_seconds': float(np.mean(training_history['epoch_time'])),
        'config': safe_json_serialize_efficientvit(CASME2_EFFICIENTVIT_CONFIG),
        'final_train_f1': float(training_history['train_f1'][-1]),
        'final_val_f1': float(training_history['val_f1'][-1]),
        'model_checkpoint': 'casme2_efficientvit_direct_best_f1.pth',
        'dataset_info': {
            'name': 'CASME_II',
            'total_samples': 255,
            'train_samples': len(train_dataset),
            'val_samples': len(val_dataset),
            'num_classes': 7,
            'class_names': CASME2_CLASSES
        },
        'architecture_info': {
            'model_type': 'EfficientViTCASME2Baseline',
            'backbone': CASME2_EFFICIENTVIT_CONFIG['efficientvit_model'],
            'variant': CASME2_EFFICIENTVIT_CONFIG['efficientvit_variant'],
            'input_size': f"{CASME2_EFFICIENTVIT_CONFIG['input_size']}x{CASME2_EFFICIENTVIT_CONFIG['input_size']}",
            'embed_dims': CASME2_EFFICIENTVIT_CONFIG['embed_dims'],
            'final_embed_dim': CASME2_EFFICIENTVIT_CONFIG['final_embed_dim'],
            'expected_params': f"{CASME2_EFFICIENTVIT_CONFIG['expected_params']}M",
            'classification_head': f'{CASME2_EFFICIENTVIT_CONFIG["final_embed_dim"]}->512->128->7'
        },
        'enhanced_features': {
            'cascaded_group_attention': True,
            'memory_efficient_attention': True,
            'fixed_checkpoint_saving': True,
            'device_migration_complete': True,
            'robust_error_handling': True,
            'multi_criteria_checkpoint_logic': True,
            'memory_optimized_training': True,
            'retry_checkpoint_logic': True
        }
    }

    # Save with proper JSON serialization
    with open(training_history_path, 'w') as f:
        json.dump(training_summary, f, indent=2)

    print(f"Enhanced EfficientViT training documentation saved: {training_history_path}")
    print(f"Experiment details: {training_summary['experiment_configuration']['loss_function']} loss")
    if CASME2_EFFICIENTVIT_CONFIG['use_focal_loss']:
        print(f"  Gamma: {CASME2_EFFICIENTVIT_CONFIG['focal_loss_gamma']}, Alpha Sum: {sum(CASME2_EFFICIENTVIT_CONFIG['focal_loss_alpha_weights']):.3f}")
    print(f"Model variant: {CASME2_EFFICIENTVIT_CONFIG['efficientvit_model']} ({CASME2_EFFICIENTVIT_CONFIG['efficientvit_variant']})")
    print(f"Checkpoint saving: FIXED with complete device migration")

except Exception as e:
    print(f"Warning: Could not save EfficientViT training documentation: {e}")
    print("Training completed successfully, but documentation export failed")

# Enhanced memory cleanup for EfficientViT
if torch.cuda.is_available():
    torch.cuda.synchronize()
    torch.cuda.empty_cache()

print("\nNext: Cell 3 - CASME II EfficientViT Enhanced Evaluation")
print("Enhanced EfficientViT training pipeline completed successfully!")
# Out:
# CASME II EfficientViT Enhanced Training Pipeline with Fixed Checkpoints
# ======================================================================
# Loss Function: Optimized Focal Loss
# Focal Loss Parameters:
#   Gamma: 2.0
#   Per-class Alpha: [0.053, 0.067, 0.094, 0.102, 0.106, 0.201, 0.376]
#   Alpha Sum: 0.999
# EfficientViT Architecture: M5 variant
# Cascaded Group Attention: Memory efficient processing
# Training epochs: 50
# Scheduler patience: 3
#
# Creating CASME II EfficientViT training datasets...
# Loading CASME II train dataset for EfficientViT training...
# Loaded 201 CASME II train samples
#   others: 79 samples (39.3%)
#   disgust: 50 samples (24.9%)
#   happiness: 25 samples (12.4%)
#   repression: 21 samples (10.4%)
#   surprise: 20 samples (10.0%)
#   sadness: 5 samples (2.5%)
#   fear: 1 samples (0.5%)
# Preloading 201 train images to RAM for EfficientViT...
# Loading train: 100%|██████████| 201/201 [02:23<00:00,  1.40it/s]
# TRAIN RAM caching completed: 201 images, ~0.36GB
# Loading CASME II val dataset for EfficientViT training...
# Loaded 26 CASME II val samples
#   others: 10 samples (38.5%)
#   disgust: 6 samples (23.1%)
#   happiness: 3 samples (11.5%)
#   repression: 3 samples (11.5%)
#   surprise: 2 samples (7.7%)
#   sadness: 1 samples (3.8%)
#   fear: 1 samples (3.8%)
# Preloading 26 val images to RAM for EfficientViT...
# Loading val: 100%|██████████| 26/26 [00:18<00:00,  1.40it/s]
# VAL RAM caching completed: 26 images, ~0.05GB
# Training batches: 13 (samples: 201)
# Validation batches: 2 (samples: 26)
#
# Initializing CASME II EfficientViT enhanced model...
# Loading TIMM EfficientViT with original head...
# EfficientViT feature dimension (extracted): 384
# Expected embed dimensions: [192, 288, 384]
# EfficientViT CASME II: 384 -> CGA -> 512 -> 128 -> 7
# Model parameters: Total=12.4M, Trainable=12.4M
# Using Optimized Focal Loss with gamma=2.0
# Per-class alpha weights: [0.053, 0.067, 0.094, 0.102, 0.106, 0.201, 0.376]
# Alpha sum: 0.999
# Scheduler: ReduceLROnPlateau monitoring val_f1_macro
# Optimizer: AdamW (LR=1e-05)
# Scheduler: ReduceLROnPlateau (patience=3)
# Criterion: Optimized Focal Loss
# EfficientViT Architecture: M5 variant
#
# Starting CASME II EfficientViT enhanced training with fixed checkpoints...
# Training configuration: 50 epochs
# Cascaded Group Attention: Memory efficient multi-head processing
# ======================================================================
#
# Epoch 1/50
# CASME II EfficientViT Training Epoch 1/50: 100%|██████████| 13/13 [00:15<00:00,  1.20s/it, Loss=0.1201, LR=1.00e-05, EffViT=m5]
# CASME II EfficientViT Validation Epoch 1/50: 100%|██████████| 2/2 [00:05<00:00,  2.99s/it, Val Loss=0.0989, EffViT=m5]
# Train - Loss: 0.1171, F1: 0.0760, Acc: 0.1144
# Val   - Loss: 0.1479, F1: 0.0617, Acc: 0.1154
# Time  - Epoch: 21.7s, LR: 1.00e-05
# Saving EfficientViT checkpoint with enhanced device migration...
#   Migrating EfficientViT model state dict to CPU...
#   Migrating optimizer state dict to CPU...
#   Migrating scheduler state dict to CPU...
#   Device migration completed successfully
#   Attempt 1: Saving to temporary file...
# EfficientViT checkpoint saved successfully: casme2_efficientvit_direct_best_f1.pth
#   EfficientViT variant: m5
#   Model: efficientvit_m5.r224_in1k
# New best EfficientViT model: Higher F1 - F1: 0.0617
# Progress: 2.0% | Best F1: 0.0617 | ETA: 18.3min | EfficientViT-M5
#
# Epoch 2/50
# CASME II EfficientViT Training Epoch 2/50: 100%|██████████| 13/13 [00:01<00:00,  8.64it/s, Loss=0.1231, LR=1.00e-05, EffViT=m5]
# CASME II EfficientViT Validation Epoch 2/50: 100%|██████████| 2/2 [00:00<00:00,  5.83it/s, Val Loss=0.1063, EffViT=m5]
# Train - Loss: 0.1207, F1: 0.0821, Acc: 0.1045
# Val   - Loss: 0.1524, F1: 0.0000, Acc: 0.0000
# Time  - Epoch: 1.9s, LR: 1.00e-05
# Progress: 4.0% | Best F1: 0.0617 | ETA: 9.7min | EfficientViT-M5
#
# Epoch 3/50
# CASME II EfficientViT Training Epoch 3/50: 100%|██████████| 13/13 [00:01<00:00,  8.50it/s, Loss=0.1177, LR=1.00e-05, EffViT=m5]
# CASME II EfficientViT Validation Epoch 3/50: 100%|██████████| 2/2 [00:00<00:00,  5.74it/s, Val Loss=0.1070, EffViT=m5]
# Train - Loss: 0.1170, F1: 0.0932, Acc: 0.1294
# Val   - Loss: 0.1518, F1: 0.0190, Acc: 0.0385
# Time  - Epoch: 1.9s, LR: 1.00e-05
# Progress: 6.0% | Best F1: 0.0617 | ETA: 6.8min | EfficientViT-M5
#
# Epoch 4/50
# CASME II EfficientViT Training Epoch 4/50: 100%|██████████| 13/13 [00:01<00:00,  8.83it/s, Loss=0.1139, LR=1.00e-05, EffViT=m5]
# CASME II EfficientViT Validation Epoch 4/50: 100%|██████████| 2/2 [00:00<00:00,  5.87it/s, Val Loss=0.1049, EffViT=m5]
# Train - Loss: 0.1164, F1: 0.1073, Acc: 0.1493
# Val   - Loss: 0.1598, F1: 0.0143, Acc: 0.0385
# Time  - Epoch: 1.8s, LR: 1.00e-05
# Progress: 8.0% | Best F1: 0.0617 | ETA: 5.4min | EfficientViT-M5
#
# Epoch 5/50
# CASME II EfficientViT Training Epoch 5/50: 100%|██████████| 13/13 [00:01<00:00,  8.53it/s, Loss=0.1175, LR=1.00e-05, EffViT=m5]
# CASME II EfficientViT Validation Epoch 5/50: 100%|██████████| 2/2 [00:00<00:00,  5.80it/s, Val Loss=0.1130, EffViT=m5]
# Train - Loss: 0.1166, F1: 0.0991, Acc: 0.1443
# Val   - Loss: 0.1648, F1: 0.0190, Acc: 0.0385
# Time  - Epoch: 1.9s, LR: 5.00e-06
# Progress: 10.0% | Best F1: 0.0617 | ETA: 4.5min | EfficientViT-M5
#
# Epoch 6/50
# CASME II EfficientViT Training Epoch 6/50: 100%|██████████| 13/13 [00:01<00:00,  8.31it/s, Loss=0.1163, LR=5.00e-06, EffViT=m5]
# CASME II EfficientViT Validation Epoch 6/50: 100%|██████████| 2/2 [00:00<00:00,  5.64it/s, Val Loss=0.1063, EffViT=m5]
# Train - Loss: 0.1167, F1: 0.1144, Acc: 0.1493
# Val   - Loss: 0.1617, F1: 0.0744, Acc: 0.1154
# Time  - Epoch: 1.9s, LR: 5.00e-06
# Saving EfficientViT checkpoint with enhanced device migration...
#   Migrating EfficientViT model state dict to CPU...
#   Migrating optimizer state dict to CPU...
#   Migrating scheduler state dict to CPU...
#   Device migration completed successfully
#   Attempt 1: Saving to temporary file...
# EfficientViT checkpoint saved successfully: casme2_efficientvit_direct_best_f1.pth
#   EfficientViT variant: m5
#   Model: efficientvit_m5.r224_in1k
# New best EfficientViT model: Higher F1 - F1: 0.0744
# Progress: 12.0% | Best F1: 0.0744 | ETA: 4.0min | EfficientViT-M5
#
# Epoch 7/50
# CASME II EfficientViT Training Epoch 7/50: 100%|██████████| 13/13 [00:01<00:00,  7.77it/s, Loss=0.1170, LR=5.00e-06, EffViT=m5]
# CASME II EfficientViT Validation Epoch 7/50: 100%|██████████| 2/2 [00:00<00:00,  5.12it/s, Val Loss=0.1115, EffViT=m5]
# Train - Loss: 0.1146, F1: 0.0998, Acc: 0.1294
# Val   - Loss: 0.1658, F1: 0.0317, Acc: 0.0769
# Time  - Epoch: 2.1s, LR: 5.00e-06
# Progress: 14.0% | Best F1: 0.0744 | ETA: 3.5min | EfficientViT-M5
#
# Epoch 8/50
# CASME II EfficientViT Training Epoch 8/50: 100%|██████████| 13/13 [00:01<00:00,  8.32it/s, Loss=0.1130, LR=5.00e-06, EffViT=m5]
# CASME II EfficientViT Validation Epoch 8/50: 100%|██████████| 2/2 [00:00<00:00,  5.53it/s, Val Loss=0.1057, EffViT=m5]
# Train - Loss: 0.1179, F1: 0.1028, Acc: 0.1393
# Val   - Loss: 0.1585, F1: 0.0381, Acc: 0.0769
# Time  - Epoch: 1.9s, LR: 5.00e-06
# Progress: 16.0% | Best F1: 0.0744 | ETA: 3.2min | EfficientViT-M5
#
# Epoch 9/50
# CASME II EfficientViT Training Epoch 9/50: 100%|██████████| 13/13 [00:01<00:00,  8.47it/s, Loss=0.1147, LR=5.00e-06, EffViT=m5]
# CASME II EfficientViT Validation Epoch 9/50: 100%|██████████| 2/2 [00:00<00:00,  5.48it/s, Val Loss=0.1041, EffViT=m5]
# Train - Loss: 0.1144, F1: 0.1378, Acc: 0.1642
# Val   - Loss: 0.1599, F1: 0.0381, Acc: 0.0769
# Time  - Epoch: 1.9s, LR: 5.00e-06
# Progress: 18.0% | Best F1: 0.0744 | ETA: 2.9min | EfficientViT-M5
#
# Epoch 10/50
# CASME II EfficientViT Training Epoch 10/50: 100%|██████████| 13/13 [00:01<00:00,  8.38it/s, Loss=0.1103, LR=5.00e-06, EffViT=m5]
# CASME II EfficientViT Validation Epoch 10/50: 100%|██████████| 2/2 [00:00<00:00,  5.41it/s, Val Loss=0.1018, EffViT=m5]
# Train - Loss: 0.1119, F1: 0.1046, Acc: 0.1493
# Val   - Loss: 0.1637, F1: 0.0317, Acc: 0.0769
# Time  - Epoch: 1.9s, LR: 2.50e-06
# Progress: 20.0% | Best F1: 0.0744 | ETA: 2.7min | EfficientViT-M5
#
# Epoch 11/50
# CASME II EfficientViT Training Epoch 11/50: 100%|██████████| 13/13 [00:01<00:00,  8.30it/s, Loss=0.1186, LR=2.50e-06, EffViT=m5]
# CASME II EfficientViT Validation Epoch 11/50: 100%|██████████| 2/2 [00:00<00:00,  5.45it/s, Val Loss=0.0968, EffViT=m5]
# Train - Loss: 0.1169, F1: 0.0846, Acc: 0.1095
# Val   - Loss: 0.1618, F1: 0.0357, Acc: 0.0769
# Time  - Epoch: 2.0s, LR: 2.50e-06
# Progress: 22.0% | Best F1: 0.0744 | ETA: 2.5min | EfficientViT-M5
#
# Epoch 12/50
# CASME II EfficientViT Training Epoch 12/50: 100%|██████████| 13/13 [00:01<00:00,  7.98it/s, Loss=0.1129, LR=2.50e-06, EffViT=m5]
# CASME II EfficientViT Validation Epoch 12/50: 100%|██████████| 2/2 [00:00<00:00,  5.37it/s, Val Loss=0.0943, EffViT=m5]
# Train - Loss: 0.1111, F1: 0.1033, Acc: 0.1592
# Val   - Loss: 0.1570, F1: 0.0381, Acc: 0.0769
# Time  - Epoch: 2.0s, LR: 2.50e-06
# Progress: 24.0% | Best F1: 0.0744 | ETA: 2.3min | EfficientViT-M5
#
# Epoch 13/50
# CASME II EfficientViT Training Epoch 13/50: 100%|██████████| 13/13 [00:01<00:00,  8.25it/s, Loss=0.1128, LR=2.50e-06, EffViT=m5]
# CASME II EfficientViT Validation Epoch 13/50: 100%|██████████| 2/2 [00:00<00:00,  5.50it/s, Val Loss=0.0995, EffViT=m5]
# Train - Loss: 0.1121, F1: 0.1097, Acc: 0.1692
# Val   - Loss: 0.1616, F1: 0.0521, Acc: 0.1154
# Time  - Epoch: 2.0s, LR: 2.50e-06
# Progress: 26.0% | Best F1: 0.0744 | ETA: 2.2min | EfficientViT-M5
#
# Epoch 14/50
# CASME II EfficientViT Training Epoch 14/50: 100%|██████████| 13/13 [00:01<00:00,  8.45it/s, Loss=0.1134, LR=2.50e-06, EffViT=m5]
# CASME II EfficientViT Validation Epoch 14/50: 100%|██████████| 2/2 [00:00<00:00,  5.42it/s, Val Loss=0.0985, EffViT=m5]
# Train - Loss: 0.1133, F1: 0.1041, Acc: 0.1493
# Val   - Loss: 0.1595, F1: 0.1009, Acc: 0.1538
# Time  - Epoch: 1.9s, LR: 2.50e-06
# Saving EfficientViT checkpoint with enhanced device migration...
#   Migrating EfficientViT model state dict to CPU...
#   Migrating optimizer state dict to CPU...
#   Migrating scheduler state dict to CPU...
#   Device migration completed successfully
#   Attempt 1: Saving to temporary file...
# EfficientViT checkpoint saved successfully: casme2_efficientvit_direct_best_f1.pth
#   EfficientViT variant: m5
#   Model: efficientvit_m5.r224_in1k
# New best EfficientViT model: Higher F1 - F1: 0.1009
# Progress: 28.0% | Best F1: 0.1009 | ETA: 2.1min | EfficientViT-M5
#
# Epoch 15/50
# CASME II EfficientViT Training Epoch 15/50: 100%|██████████| 13/13 [00:01<00:00,  8.33it/s, Loss=0.1147, LR=2.50e-06, EffViT=m5]
# CASME II EfficientViT Validation Epoch 15/50: 100%|██████████| 2/2 [00:00<00:00,  5.29it/s, Val Loss=0.0950, EffViT=m5]
# Train - Loss: 0.1150, F1: 0.0854, Acc: 0.1194
# Val   - Loss: 0.1618, F1: 0.0952, Acc: 0.1538
# Time  - Epoch: 2.0s, LR: 2.50e-06
# Progress: 30.0% | Best F1: 0.1009 | ETA: 2.0min | EfficientViT-M5
#
# Epoch 16/50
# CASME II EfficientViT Training Epoch 16/50: 100%|██████████| 13/13 [00:01<00:00,  8.47it/s, Loss=0.1076, LR=2.50e-06, EffViT=m5]
# CASME II EfficientViT Validation Epoch 16/50: 100%|██████████| 2/2 [00:00<00:00,  5.25it/s, Val Loss=0.0964, EffViT=m5]
# Train - Loss: 0.1075, F1: 0.1471, Acc: 0.1990
# Val   - Loss: 0.1606, F1: 0.0888, Acc: 0.1538
# Time  - Epoch: 1.9s, LR: 2.50e-06
# Progress: 32.0% | Best F1: 0.1009 | ETA: 1.9min | EfficientViT-M5
#
# Epoch 17/50
# CASME II EfficientViT Training Epoch 17/50: 100%|██████████| 13/13 [00:01<00:00,  8.27it/s, Loss=0.1071, LR=2.50e-06, EffViT=m5]
# CASME II EfficientViT Validation Epoch 17/50: 100%|██████████| 2/2 [00:00<00:00,  5.29it/s, Val Loss=0.0924, EffViT=m5]
# Train - Loss: 0.1084, F1: 0.1518, Acc: 0.1891
# Val   - Loss: 0.1549, F1: 0.0913, Acc: 0.1538
# Time  - Epoch: 2.0s, LR: 2.50e-06
# Progress: 34.0% | Best F1: 0.1009 | ETA: 1.8min | EfficientViT-M5
#
# Epoch 18/50
# CASME II EfficientViT Training Epoch 18/50: 100%|██████████| 13/13 [00:01<00:00,  8.24it/s, Loss=0.1074, LR=2.50e-06, EffViT=m5]
# CASME II EfficientViT Validation Epoch 18/50: 100%|██████████| 2/2 [00:00<00:00,  5.34it/s, Val Loss=0.0941, EffViT=m5]
# Train - Loss: 0.1098, F1: 0.1171, Acc: 0.1642
# Val   - Loss: 0.1587, F1: 0.0985, Acc: 0.1538
# Time  - Epoch: 2.0s, LR: 1.25e-06
# Progress: 36.0% | Best F1: 0.1009 | ETA: 1.7min | EfficientViT-M5
#
# Epoch 19/50
# CASME II EfficientViT Training Epoch 19/50: 100%|██████████| 13/13 [00:01<00:00,  8.30it/s, Loss=0.1129, LR=1.25e-06, EffViT=m5]
# CASME II EfficientViT Validation Epoch 19/50: 100%|██████████| 2/2 [00:00<00:00,  5.24it/s, Val Loss=0.0923, EffViT=m5]
# Train - Loss: 0.1122, F1: 0.1197, Acc: 0.1542
# Val   - Loss: 0.1593, F1: 0.0698, Acc: 0.1154
# Time  - Epoch: 2.0s, LR: 1.25e-06
# Progress: 38.0% | Best F1: 0.1009 | ETA: 1.6min | EfficientViT-M5
#
# Epoch 20/50
# CASME II EfficientViT Training Epoch 20/50: 100%|██████████| 13/13 [00:01<00:00,  8.39it/s, Loss=0.1140, LR=1.25e-06, EffViT=m5]
# CASME II EfficientViT Validation Epoch 20/50: 100%|██████████| 2/2 [00:00<00:00,  5.07it/s, Val Loss=0.0947, EffViT=m5]
# Train - Loss: 0.1116, F1: 0.1238, Acc: 0.1642
# Val   - Loss: 0.1584, F1: 0.0781, Acc: 0.1154
# Time  - Epoch: 2.0s, LR: 1.25e-06
# Progress: 40.0% | Best F1: 0.1009 | ETA: 1.5min | EfficientViT-M5
#
# Epoch 21/50
# CASME II EfficientViT Training Epoch 21/50: 100%|██████████| 13/13 [00:01<00:00,  7.95it/s, Loss=0.1108, LR=1.25e-06, EffViT=m5]
# CASME II EfficientViT Validation Epoch 21/50: 100%|██████████| 2/2 [00:00<00:00,  5.13it/s, Val Loss=0.0944, EffViT=m5]
# Train - Loss: 0.1105, F1: 0.1551, Acc: 0.1891
# Val   - Loss: 0.1573, F1: 0.0698, Acc: 0.1154
# Time  - Epoch: 2.0s, LR: 1.25e-06
# Progress: 42.0% | Best F1: 0.1009 | ETA: 1.4min | EfficientViT-M5
#
# Epoch 22/50
# CASME II EfficientViT Training Epoch 22/50: 100%|██████████| 13/13 [00:01<00:00,  8.20it/s, Loss=0.1048, LR=1.25e-06, EffViT=m5]
# CASME II EfficientViT Validation Epoch 22/50: 100%|██████████| 2/2 [00:00<00:00,  5.26it/s, Val Loss=0.0930, EffViT=m5]
# Train - Loss: 0.1065, F1: 0.1289, Acc: 0.2090
# Val   - Loss: 0.1611, F1: 0.0561, Acc: 0.1154
# Time  - Epoch: 2.0s, LR: 1.00e-06
# Progress: 44.0% | Best F1: 0.1009 | ETA: 1.4min | EfficientViT-M5
#
# Epoch 23/50
# CASME II EfficientViT Training Epoch 23/50: 100%|██████████| 13/13 [00:01<00:00,  8.13it/s, Loss=0.1163, LR=1.00e-06, EffViT=m5]
# CASME II EfficientViT Validation Epoch 23/50: 100%|██████████| 2/2 [00:00<00:00,  5.30it/s, Val Loss=0.0940, EffViT=m5]
# Train - Loss: 0.1125, F1: 0.1407, Acc: 0.2040
# Val   - Loss: 0.1601, F1: 0.0537, Acc: 0.0769
# Time  - Epoch: 2.0s, LR: 1.00e-06
# Progress: 46.0% | Best F1: 0.1009 | ETA: 1.3min | EfficientViT-M5
#
# Epoch 24/50
# CASME II EfficientViT Training Epoch 24/50: 100%|██████████| 13/13 [00:01<00:00,  8.17it/s, Loss=0.1102, LR=1.00e-06, EffViT=m5]
# CASME II EfficientViT Validation Epoch 24/50: 100%|██████████| 2/2 [00:00<00:00,  5.11it/s, Val Loss=0.0941, EffViT=m5]
# Train - Loss: 0.1097, F1: 0.1700, Acc: 0.1940
# Val   - Loss: 0.1585, F1: 0.0918, Acc: 0.1538
# Time  - Epoch: 2.0s, LR: 1.00e-06
# Progress: 48.0% | Best F1: 0.1009 | ETA: 1.2min | EfficientViT-M5
#
# Epoch 25/50
# CASME II EfficientViT Training Epoch 25/50: 100%|██████████| 13/13 [00:01<00:00,  8.04it/s, Loss=0.1118, LR=1.00e-06, EffViT=m5]
# CASME II EfficientViT Validation Epoch 25/50: 100%|██████████| 2/2 [00:00<00:00,  5.37it/s, Val Loss=0.0915, EffViT=m5]
# Train - Loss: 0.1100, F1: 0.1272, Acc: 0.1791
# Val   - Loss: 0.1554, F1: 0.1020, Acc: 0.1923
# Time  - Epoch: 2.0s, LR: 1.00e-06
# Saving EfficientViT checkpoint with enhanced device migration...
#   Migrating EfficientViT model state dict to CPU...
#   Migrating optimizer state dict to CPU...
#   Migrating scheduler state dict to CPU...
#   Device migration completed successfully
#   Attempt 1: Saving to temporary file...
# EfficientViT checkpoint saved successfully: casme2_efficientvit_direct_best_f1.pth
#   EfficientViT variant: m5
#   Model: efficientvit_m5.r224_in1k
# New best EfficientViT model: Higher F1 - F1: 0.1020
# Progress: 50.0% | Best F1: 0.1020 | ETA: 1.2min | EfficientViT-M5
#
# Epoch 26/50
# CASME II EfficientViT Training Epoch 26/50: 100%|██████████| 13/13 [00:01<00:00,  8.05it/s, Loss=0.1088, LR=1.00e-06, EffViT=m5]
# CASME II EfficientViT Validation Epoch 26/50: 100%|██████████| 2/2 [00:00<00:00,  5.21it/s, Val Loss=0.0897, EffViT=m5]
# Train - Loss: 0.1101, F1: 0.1418, Acc: 0.1990
# Val   - Loss: 0.1504, F1: 0.0958, Acc: 0.1538
# Time  - Epoch: 2.0s, LR: 1.00e-06
# Progress: 52.0% | Best F1: 0.1020 | ETA: 1.1min | EfficientViT-M5
#
# Epoch 27/50
# CASME II EfficientViT Training Epoch 27/50: 100%|██████████| 13/13 [00:01<00:00,  8.20it/s, Loss=0.1131, LR=1.00e-06, EffViT=m5]
# CASME II EfficientViT Validation Epoch 27/50: 100%|██████████| 2/2 [00:00<00:00,  5.30it/s, Val Loss=0.0887, EffViT=m5]
# Train - Loss: 0.1131, F1: 0.0926, Acc: 0.1443
# Val   - Loss: 0.1609, F1: 0.1352, Acc: 0.2308
# Time  - Epoch: 2.0s, LR: 1.00e-06
# Saving EfficientViT checkpoint with enhanced device migration...
#   Migrating EfficientViT model state dict to CPU...
#   Migrating optimizer state dict to CPU...
#   Migrating scheduler state dict to CPU...
#   Device migration completed successfully
#   Attempt 1: Saving to temporary file...
# EfficientViT checkpoint saved successfully: casme2_efficientvit_direct_best_f1.pth
#   EfficientViT variant: m5
#   Model: efficientvit_m5.r224_in1k
# New best EfficientViT model: Higher F1 - F1: 0.1352
# Progress: 54.0% | Best F1: 0.1352 | ETA: 1.1min | EfficientViT-M5
#
# Epoch 28/50
# CASME II EfficientViT Training Epoch 28/50: 100%|██████████| 13/13 [00:01<00:00,  8.12it/s, Loss=0.1075, LR=1.00e-06, EffViT=m5]
# CASME II EfficientViT Validation Epoch 28/50: 100%|██████████| 2/2 [00:00<00:00,  5.20it/s, Val Loss=0.0911, EffViT=m5]
# Train - Loss: 0.1086, F1: 0.1534, Acc: 0.2040
# Val   - Loss: 0.1578, F1: 0.0825, Acc: 0.1154
# Time  - Epoch: 2.0s, LR: 1.00e-06
# Progress: 56.0% | Best F1: 0.1352 | ETA: 1.0min | EfficientViT-M5
#
# Epoch 29/50
# CASME II EfficientViT Training Epoch 29/50: 100%|██████████| 13/13 [00:01<00:00,  8.06it/s, Loss=0.1154, LR=1.00e-06, EffViT=m5]
# CASME II EfficientViT Validation Epoch 29/50: 100%|██████████| 2/2 [00:00<00:00,  5.06it/s, Val Loss=0.0874, EffViT=m5]
# Train - Loss: 0.1180, F1: 0.0880, Acc: 0.1294
# Val   - Loss: 0.1510, F1: 0.1117, Acc: 0.1923
# Time  - Epoch: 2.0s, LR: 1.00e-06
# Progress: 58.0% | Best F1: 0.1352 | ETA: 1.0min | EfficientViT-M5
#
# Epoch 30/50
# CASME II EfficientViT Training Epoch 30/50: 100%|██████████| 13/13 [00:01<00:00,  7.91it/s, Loss=0.1061, LR=1.00e-06, EffViT=m5]
# CASME II EfficientViT Validation Epoch 30/50: 100%|██████████| 2/2 [00:00<00:00,  5.26it/s, Val Loss=0.0901, EffViT=m5]
# Train - Loss: 0.1112, F1: 0.1345, Acc: 0.1940
# Val   - Loss: 0.1539, F1: 0.0595, Acc: 0.1154
# Time  - Epoch: 2.0s, LR: 1.00e-06
# Progress: 60.0% | Best F1: 0.1352 | ETA: 0.9min | EfficientViT-M5
#
# Epoch 31/50
# CASME II EfficientViT Training Epoch 31/50: 100%|██████████| 13/13 [00:01<00:00,  8.13it/s, Loss=0.1132, LR=1.00e-06, EffViT=m5]
# CASME II EfficientViT Validation Epoch 31/50: 100%|██████████| 2/2 [00:00<00:00,  5.21it/s, Val Loss=0.0924, EffViT=m5]
# Train - Loss: 0.1134, F1: 0.1254, Acc: 0.1841
# Val   - Loss: 0.1519, F1: 0.0881, Acc: 0.1538
# Time  - Epoch: 2.0s, LR: 1.00e-06
# Progress: 62.0% | Best F1: 0.1352 | ETA: 0.9min | EfficientViT-M5
#
# Epoch 32/50
# CASME II EfficientViT Training Epoch 32/50: 100%|██████████| 13/13 [00:01<00:00,  8.06it/s, Loss=0.1134, LR=1.00e-06, EffViT=m5]
# CASME II EfficientViT Validation Epoch 32/50: 100%|██████████| 2/2 [00:00<00:00,  5.15it/s, Val Loss=0.0936, EffViT=m5]
# Train - Loss: 0.1111, F1: 0.1289, Acc: 0.1741
# Val   - Loss: 0.1546, F1: 0.0667, Acc: 0.0769
# Time  - Epoch: 2.0s, LR: 1.00e-06
# Progress: 64.0% | Best F1: 0.1352 | ETA: 0.8min | EfficientViT-M5
#
# Epoch 33/50
# CASME II EfficientViT Training Epoch 33/50: 100%|██████████| 13/13 [00:01<00:00,  8.22it/s, Loss=0.1066, LR=1.00e-06, EffViT=m5]
# CASME II EfficientViT Validation Epoch 33/50: 100%|██████████| 2/2 [00:00<00:00,  4.88it/s, Val Loss=0.0916, EffViT=m5]
# Train - Loss: 0.1076, F1: 0.1510, Acc: 0.2189
# Val   - Loss: 0.1587, F1: 0.0601, Acc: 0.1154
# Time  - Epoch: 2.0s, LR: 1.00e-06
# Progress: 66.0% | Best F1: 0.1352 | ETA: 0.8min | EfficientViT-M5
#
# Epoch 34/50
# CASME II EfficientViT Training Epoch 34/50: 100%|██████████| 13/13 [00:01<00:00,  8.25it/s, Loss=0.1138, LR=1.00e-06, EffViT=m5]
# CASME II EfficientViT Validation Epoch 34/50: 100%|██████████| 2/2 [00:00<00:00,  5.03it/s, Val Loss=0.0904, EffViT=m5]
# Train - Loss: 0.1125, F1: 0.1496, Acc: 0.1940
# Val   - Loss: 0.1564, F1: 0.0977, Acc: 0.1538
# Time  - Epoch: 2.0s, LR: 1.00e-06
# Progress: 68.0% | Best F1: 0.1352 | ETA: 0.7min | EfficientViT-M5
#
# Epoch 35/50
# CASME II EfficientViT Training Epoch 35/50: 100%|██████████| 13/13 [00:01<00:00,  8.10it/s, Loss=0.1106, LR=1.00e-06, EffViT=m5]
# CASME II EfficientViT Validation Epoch 35/50: 100%|██████████| 2/2 [00:00<00:00,  4.99it/s, Val Loss=0.0873, EffViT=m5]
# Train - Loss: 0.1087, F1: 0.1480, Acc: 0.2239
# Val   - Loss: 0.1547, F1: 0.1265, Acc: 0.2308
# Time  - Epoch: 2.0s, LR: 1.00e-06
# Progress: 70.0% | Best F1: 0.1352 | ETA: 0.7min | EfficientViT-M5
#
# Epoch 36/50
# CASME II EfficientViT Training Epoch 36/50: 100%|██████████| 13/13 [00:01<00:00,  7.87it/s, Loss=0.1049, LR=1.00e-06, EffViT=m5]
# CASME II EfficientViT Validation Epoch 36/50: 100%|██████████| 2/2 [00:00<00:00,  5.01it/s, Val Loss=0.0891, EffViT=m5]
# Train - Loss: 0.1103, F1: 0.1150, Acc: 0.1791
# Val   - Loss: 0.1555, F1: 0.0932, Acc: 0.1538
# Time  - Epoch: 2.1s, LR: 1.00e-06
# Progress: 72.0% | Best F1: 0.1352 | ETA: 0.6min | EfficientViT-M5
#
# Epoch 37/50
# CASME II EfficientViT Training Epoch 37/50: 100%|██████████| 13/13 [00:01<00:00,  7.96it/s, Loss=0.1085, LR=1.00e-06, EffViT=m5]
# CASME II EfficientViT Validation Epoch 37/50: 100%|██████████| 2/2 [00:00<00:00,  5.33it/s, Val Loss=0.0902, EffViT=m5]
# Train - Loss: 0.1090, F1: 0.1499, Acc: 0.1940
# Val   - Loss: 0.1517, F1: 0.1165, Acc: 0.1923
# Time  - Epoch: 2.0s, LR: 1.00e-06
# Progress: 74.0% | Best F1: 0.1352 | ETA: 0.6min | EfficientViT-M5
#
# Epoch 38/50
# CASME II EfficientViT Training Epoch 38/50: 100%|██████████| 13/13 [00:01<00:00,  8.25it/s, Loss=0.1092, LR=1.00e-06, EffViT=m5]
# CASME II EfficientViT Validation Epoch 38/50: 100%|██████████| 2/2 [00:00<00:00,  5.35it/s, Val Loss=0.0889, EffViT=m5]
# Train - Loss: 0.1123, F1: 0.1184, Acc: 0.1940
# Val   - Loss: 0.1548, F1: 0.0440, Acc: 0.0769
# Time  - Epoch: 2.0s, LR: 1.00e-06
# Progress: 76.0% | Best F1: 0.1352 | ETA: 0.5min | EfficientViT-M5
#
# Epoch 39/50
# CASME II EfficientViT Training Epoch 39/50: 100%|██████████| 13/13 [00:01<00:00,  8.41it/s, Loss=0.1084, LR=1.00e-06, EffViT=m5]
# CASME II EfficientViT Validation Epoch 39/50: 100%|██████████| 2/2 [00:00<00:00,  5.29it/s, Val Loss=0.0897, EffViT=m5]
# Train - Loss: 0.1081, F1: 0.1514, Acc: 0.1990
# Val   - Loss: 0.1550, F1: 0.0985, Acc: 0.1538
# Time  - Epoch: 1.9s, LR: 1.00e-06
# Progress: 78.0% | Best F1: 0.1352 | ETA: 0.5min | EfficientViT-M5
#
# Epoch 40/50
# CASME II EfficientViT Training Epoch 40/50: 100%|██████████| 13/13 [00:01<00:00,  8.28it/s, Loss=0.1145, LR=1.00e-06, EffViT=m5]
# CASME II EfficientViT Validation Epoch 40/50: 100%|██████████| 2/2 [00:00<00:00,  5.17it/s, Val Loss=0.0925, EffViT=m5]
# Train - Loss: 0.1111, F1: 0.1239, Acc: 0.1990
# Val   - Loss: 0.1568, F1: 0.0714, Acc: 0.1154
# Time  - Epoch: 2.0s, LR: 1.00e-06
# Progress: 80.0% | Best F1: 0.1352 | ETA: 0.4min | EfficientViT-M5
#
# Epoch 41/50
# CASME II EfficientViT Training Epoch 41/50: 100%|██████████| 13/13 [00:01<00:00,  8.27it/s, Loss=0.1089, LR=1.00e-06, EffViT=m5]
# CASME II EfficientViT Validation Epoch 41/50: 100%|██████████| 2/2 [00:00<00:00,  5.19it/s, Val Loss=0.0895, EffViT=m5]
# Train - Loss: 0.1116, F1: 0.1170, Acc: 0.1741
# Val   - Loss: 0.1493, F1: 0.1230, Acc: 0.1923
# Time  - Epoch: 2.0s, LR: 1.00e-06
# Progress: 82.0% | Best F1: 0.1352 | ETA: 0.4min | EfficientViT-M5
#
# Epoch 42/50
# CASME II EfficientViT Training Epoch 42/50: 100%|██████████| 13/13 [00:01<00:00,  7.77it/s, Loss=0.1081, LR=1.00e-06, EffViT=m5]
# CASME II EfficientViT Validation Epoch 42/50: 100%|██████████| 2/2 [00:00<00:00,  5.16it/s, Val Loss=0.0890, EffViT=m5]
# Train - Loss: 0.1084, F1: 0.1435, Acc: 0.1940
# Val   - Loss: 0.1538, F1: 0.1333, Acc: 0.2308
# Time  - Epoch: 2.1s, LR: 1.00e-06
# Progress: 84.0% | Best F1: 0.1352 | ETA: 0.3min | EfficientViT-M5
#
# Epoch 43/50
# CASME II EfficientViT Training Epoch 43/50: 100%|██████████| 13/13 [00:01<00:00,  8.14it/s, Loss=0.1121, LR=1.00e-06, EffViT=m5]
# CASME II EfficientViT Validation Epoch 43/50: 100%|██████████| 2/2 [00:00<00:00,  5.24it/s, Val Loss=0.0916, EffViT=m5]
# Train - Loss: 0.1110, F1: 0.1380, Acc: 0.1891
# Val   - Loss: 0.1572, F1: 0.0789, Acc: 0.1538
# Time  - Epoch: 2.0s, LR: 1.00e-06
# Progress: 86.0% | Best F1: 0.1352 | ETA: 0.3min | EfficientViT-M5
#
# Epoch 44/50
# CASME II EfficientViT Training Epoch 44/50: 100%|██████████| 13/13 [00:01<00:00,  8.28it/s, Loss=0.1082, LR=1.00e-06, EffViT=m5]
# CASME II EfficientViT Validation Epoch 44/50: 100%|██████████| 2/2 [00:00<00:00,  5.19it/s, Val Loss=0.0881, EffViT=m5]
# Train - Loss: 0.1080, F1: 0.1031, Acc: 0.1642
# Val   - Loss: 0.1616, F1: 0.0646, Acc: 0.1154
# Time  - Epoch: 2.0s, LR: 1.00e-06
# Progress: 88.0% | Best F1: 0.1352 | ETA: 0.2min | EfficientViT-M5
#
# Epoch 45/50
# CASME II EfficientViT Training Epoch 45/50: 100%|██████████| 13/13 [00:01<00:00,  8.23it/s, Loss=0.1128, LR=1.00e-06, EffViT=m5]
# CASME II EfficientViT Validation Epoch 45/50: 100%|██████████| 2/2 [00:00<00:00,  5.18it/s, Val Loss=0.0881, EffViT=m5]
# Train - Loss: 0.1110, F1: 0.1198, Acc: 0.1841
# Val   - Loss: 0.1511, F1: 0.1333, Acc: 0.2308
# Time  - Epoch: 2.0s, LR: 1.00e-06
# Progress: 90.0% | Best F1: 0.1352 | ETA: 0.2min | EfficientViT-M5
#
# Epoch 46/50
# CASME II EfficientViT Training Epoch 46/50: 100%|██████████| 13/13 [00:01<00:00,  8.21it/s, Loss=0.1116, LR=1.00e-06, EffViT=m5]
# CASME II EfficientViT Validation Epoch 46/50: 100%|██████████| 2/2 [00:00<00:00,  5.26it/s, Val Loss=0.0927, EffViT=m5]
# Train - Loss: 0.1108, F1: 0.1046, Acc: 0.1592
# Val   - Loss: 0.1473, F1: 0.1009, Acc: 0.1538
# Time  - Epoch: 2.0s, LR: 1.00e-06
# Progress: 92.0% | Best F1: 0.1352 | ETA: 0.2min | EfficientViT-M5
#
# Epoch 47/50
# CASME II EfficientViT Training Epoch 47/50: 100%|██████████| 13/13 [00:01<00:00,  8.26it/s, Loss=0.1042, LR=1.00e-06, EffViT=m5]
# CASME II EfficientViT Validation Epoch 47/50: 100%|██████████| 2/2 [00:00<00:00,  5.12it/s, Val Loss=0.0871, EffViT=m5]
# Train - Loss: 0.1098, F1: 0.1166, Acc: 0.1741
# Val   - Loss: 0.1498, F1: 0.0984, Acc: 0.1538
# Time  - Epoch: 2.0s, LR: 1.00e-06
# Progress: 94.0% | Best F1: 0.1352 | ETA: 0.1min | EfficientViT-M5
#
# Epoch 48/50
# CASME II EfficientViT Training Epoch 48/50: 100%|██████████| 13/13 [00:01<00:00,  8.01it/s, Loss=0.1093, LR=1.00e-06, EffViT=m5]
# CASME II EfficientViT Validation Epoch 48/50: 100%|██████████| 2/2 [00:00<00:00,  4.93it/s, Val Loss=0.0885, EffViT=m5]
# Train - Loss: 0.1131, F1: 0.1349, Acc: 0.2040
# Val   - Loss: 0.1500, F1: 0.1025, Acc: 0.1538
# Time  - Epoch: 2.0s, LR: 1.00e-06
# Progress: 96.0% | Best F1: 0.1352 | ETA: 0.1min | EfficientViT-M5
#
# Epoch 49/50
# CASME II EfficientViT Training Epoch 49/50: 100%|██████████| 13/13 [00:01<00:00,  8.01it/s, Loss=0.1096, LR=1.00e-06, EffViT=m5]
# CASME II EfficientViT Validation Epoch 49/50: 100%|██████████| 2/2 [00:00<00:00,  5.10it/s, Val Loss=0.0862, EffViT=m5]
# Train - Loss: 0.1091, F1: 0.1439, Acc: 0.1990
# Val   - Loss: 0.1551, F1: 0.1106, Acc: 0.1923
# Time  - Epoch: 2.0s, LR: 1.00e-06
# Progress: 98.0% | Best F1: 0.1352 | ETA: 0.0min | EfficientViT-M5
#
# Epoch 50/50
# CASME II EfficientViT Training Epoch 50/50: 100%|██████████| 13/13 [00:01<00:00,  8.03it/s, Loss=0.1063, LR=1.00e-06, EffViT=m5]
# CASME II EfficientViT Validation Epoch 50/50: 100%|██████████| 2/2 [00:00<00:00,  5.32it/s, Val Loss=0.0878, EffViT=m5]
# Train - Loss: 0.1070, F1: 0.1414, Acc: 0.2289
# Val   - Loss: 0.1618, F1: 0.1328, Acc: 0.1923
# Time  - Epoch: 2.0s, LR: 1.00e-06
# Progress: 100.0% | Best F1: 0.1352 | ETA: 0.0min | EfficientViT-M5
#
# ======================================================================
# CASME II EFFICIENTVIT ENHANCED BASELINE TRAINING COMPLETED
# ======================================================================
# Training time: 2.0 minutes
# Epochs completed: 50
# Best validation F1: 0.1352 (epoch 27)
# Final train F1: 0.1414
# Final validation F1: 0.1328
# EfficientViT Architecture: M5 variant
#
# Exporting enhanced EfficientViT training documentation...
# Enhanced EfficientViT training documentation saved: /content/drive/MyDrive/RESEARCH-WORKSPACE/ACTIVE-PROJECTS/Thesis_MER_Project/results/02_03_efficientvit_direct/training_logs/casme2_efficientvit_direct_training_history.json
# Experiment details: Optimized Focal Loss loss
#   Gamma: 2.0, Alpha Sum: 0.999
# Model variant: efficientvit_m5.r224_in1k (m5)
# Checkpoint saving: FIXED with complete device migration
#
# Next: Cell 3 - CASME II EfficientViT Enhanced Evaluation
# Enhanced EfficientViT training pipeline completed successfully!

# %%
# @title Cell 3: CASME II EfficientViT Direct Baseline Evaluation

# File: 02_03_EfficientViT_Direct_Baseline_Cell3.py
# Location: experiments/02_03_EfficientViT_Direct_Baseline.ipynb
# Purpose: Evaluation framework for trained CASME II EfficientViT micro-expression recognition model

import os
import time
import json
import numpy as np
import pandas as pd
from tqdm import tqdm
from datetime import datetime

# Evaluation specific imports
from sklearn.metrics import (
    accuracy_score, precision_recall_fscore_support,
    classification_report, confusion_matrix,
    roc_curve, auc
)
from sklearn.preprocessing import label_binarize
from concurrent.futures import ThreadPoolExecutor
import multiprocessing as mp
import pickle
import warnings
warnings.filterwarnings('ignore')

# Enhanced test dataset for CASME II EfficientViT evaluation
class CASME2DatasetEvaluationEfficientViT(Dataset):
    """Enhanced CASME II test dataset with comprehensive evaluation support for EfficientViT"""

    def __init__(self, split_metadata, dataset_root, transform=None, split='test', use_ram_cache=True):
        self.metadata = split_metadata[split]['samples']
        self.dataset_root = dataset_root
        self.transform = transform
        self.split = split
        self.use_ram_cache = use_ram_cache
        self.images = []
        self.labels = []
        self.sample_ids = []
        self.emotions = []
        self.subjects = []
        self.cached_images = []

        print(f"Loading CASME II {split} dataset for EfficientViT evaluation...")

        # Process metadata for evaluation
        for sample in self.metadata:
            image_path = os.path.join(dataset_root, split, sample['image_filename'])
            self.images.append(image_path)
            self.labels.append(CLASS_TO_IDX[sample['emotion']])
            self.sample_ids.append(sample['sample_id'])
            self.emotions.append(sample['emotion'])
            self.subjects.append(sample['subject'])

        print(f"Loaded {len(self.images)} CASME II {split} samples for EfficientViT evaluation")
        self._print_evaluation_distribution()

        # RAM caching for fast evaluation
        if self.use_ram_cache:
            self._preload_to_ram_evaluation()

    def _print_evaluation_distribution(self):
        """Print comprehensive distribution for evaluation analysis"""
        if len(self.labels) == 0:
            print("No test samples found!")
            return

        label_counts = {}
        subject_counts = {}

        for label, subject in zip(self.labels, self.subjects):
            label_counts[label] = label_counts.get(label, 0) + 1
            subject_counts[subject] = subject_counts.get(subject, 0) + 1

        print("Test set class distribution:")
        for label, count in sorted(label_counts.items()):
            class_name = CASME2_CLASSES[label]
            percentage = (count / len(self.labels)) * 100
            print(f"  {class_name}: {count} samples ({percentage:.1f}%)")

        print(f"Test set covers {len(subject_counts)} subjects")

        # Check for missing classes
        missing_classes = []
        for i, class_name in enumerate(CASME2_CLASSES):
            if i not in label_counts:
                missing_classes.append(class_name)

        if missing_classes:
            print(f"Missing classes in test set: {missing_classes}")

    def _preload_to_ram_evaluation(self):
        """RAM preloading optimized for EfficientViT evaluation"""
        print(f"Preloading {len(self.images)} test images to RAM for EfficientViT evaluation...")

        valid_images = 0
        self.cached_images = [None] * len(self.images)

        # Simple loading for evaluation stability
        for i, img_path in enumerate(tqdm(self.images, desc="Loading test images")):
            try:
                image = Image.open(img_path).convert('RGB')
                if image.size != (384, 384):
                    image = image.resize((384, 384), Image.Resampling.LANCZOS)
                self.cached_images[i] = image
                valid_images += 1
            except Exception as e:
                print(f"Error loading {img_path}: {e}")
                # Create neutral placeholder
                self.cached_images[i] = Image.new('RGB', (384, 384), (128, 128, 128))

        ram_usage_gb = len(self.cached_images) * 384 * 384 * 3 * 4 / 1e9
        print(f"Test RAM caching completed: {valid_images} valid images, ~{ram_usage_gb:.2f}GB")

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        if self.use_ram_cache and self.cached_images[idx] is not None:
            image = self.cached_images[idx].copy()
        else:
            try:
                image = Image.open(self.images[idx]).convert('RGB')
                if image.size != (384, 384):
                    image = image.resize((384, 384), Image.Resampling.LANCZOS)
            except:
                image = Image.new('RGB', (384, 384), (128, 128, 128))

        if self.transform:
            image = self.transform(image)

        return (image, self.labels[idx], self.sample_ids[idx],
                self.emotions[idx], self.subjects[idx], os.path.basename(self.images[idx]))

# CASME II EfficientViT evaluation configuration
EVALUATION_CONFIG_CASME2_EFFICIENTVIT = {
    'model_type': 'EfficientViT_CASME2_Direct_Baseline',
    'task_type': 'micro_expression_recognition',
    'num_classes': 7,
    'class_names': CASME2_CLASSES,
    'checkpoint_file': 'casme2_efficientvit_direct_best_f1.pth',
    'dataset_name': 'CASME_II',
    'input_size': '384x384',
    'evaluation_protocol': 'stratified_split',
    'architecture': 'efficientvit_cascaded_group_attention'
}

print("CASME II EfficientViT Direct Baseline Evaluation Framework")
print("=" * 60)
print(f"Model: {EVALUATION_CONFIG_CASME2_EFFICIENTVIT['model_type']}")
print(f"Task: {EVALUATION_CONFIG_CASME2_EFFICIENTVIT['task_type']}")
print(f"Classes: {EVALUATION_CONFIG_CASME2_EFFICIENTVIT['class_names']}")
print(f"Input size: {EVALUATION_CONFIG_CASME2_EFFICIENTVIT['input_size']}")
print(f"Architecture: {EVALUATION_CONFIG_CASME2_EFFICIENTVIT['architecture']}")

def extract_logits_safe_casme2_efficientvit(outputs_all):
    """Robust logits extraction for CASME II EfficientViT TIMM model"""
    # EfficientViT from TIMM returns direct tensor output
    if isinstance(outputs_all, torch.Tensor):
        return outputs_all

    # Handle potential tuple/list outputs from TIMM models
    if isinstance(outputs_all, (tuple, list)):
        for item in outputs_all:
            if isinstance(item, torch.Tensor):
                return item

    # Handle dictionary outputs (less common for TIMM EfficientViT)
    if isinstance(outputs_all, dict):
        for key in ('logits', 'logit', 'predictions', 'outputs', 'scores'):
            value = outputs_all.get(key)
            if isinstance(value, torch.Tensor):
                return value
        # Fallback to first tensor value
        for value in outputs_all.values():
            if isinstance(value, torch.Tensor):
                return value

    raise RuntimeError("Unable to extract tensor logits from CASME II EfficientViT TIMM model output")

def load_trained_model_casme2_efficientvit(checkpoint_path, device):
    """Load trained CASME II EfficientViT model with TIMM compatibility"""
    print(f"Loading trained CASME II EfficientViT model from: {checkpoint_path}")

    if not os.path.exists(checkpoint_path):
        raise FileNotFoundError(f"EfficientViT checkpoint not found: {checkpoint_path}")

    # Multiple loading approaches for maximum compatibility
    checkpoint = None
    loading_method = "unknown"

    try:
        checkpoint = torch.load(checkpoint_path, map_location='cpu')
        loading_method = "standard"
    except Exception as e1:
        try:
            checkpoint = torch.load(checkpoint_path, map_location=device, weights_only=False)
            loading_method = "weights_only_false"
        except Exception as e2:
            try:
                import pickle
                with open(checkpoint_path, 'rb') as f:
                    checkpoint = pickle.load(f)
                loading_method = "pickle"
            except Exception as e3:
                raise RuntimeError(f"All EfficientViT loading methods failed: {e1}, {e2}, {e3}")

    print(f"EfficientViT checkpoint loaded using: {loading_method}")

    # Extract EfficientViT-specific configuration
    efficientvit_config = checkpoint.get('casme2_efficientvit_config', {})
    efficientvit_variant = checkpoint.get('efficientvit_variant', 'm4')
    efficientvit_model_name = checkpoint.get('efficientvit_model', 'efficientvit_m4.r224_in1k')

    print(f"Detected EfficientViT variant: {efficientvit_variant}")
    print(f"Detected EfficientViT model: {efficientvit_model_name}")

    # Initialize CASME II EfficientViT model with detected configuration
    model = EfficientViTCASME2Baseline(
        num_classes=EVALUATION_CONFIG_CASME2_EFFICIENTVIT['num_classes'],
        dropout_rate=efficientvit_config.get('dropout_rate', 0.2)
    ).to(device)

    # Load state dict with fallback approaches
    state_dict = checkpoint.get('model_state_dict', checkpoint)

    try:
        model.load_state_dict(state_dict, strict=True)
        print("EfficientViT model state loaded with strict=True")
    except Exception as e:
        print(f"Strict loading failed, trying non-strict: {str(e)[:100]}...")
        try:
            missing_keys, unexpected_keys = model.load_state_dict(state_dict, strict=False)
            if missing_keys or unexpected_keys:
                print(f"Non-strict loading: Missing {len(missing_keys)}, Unexpected {len(unexpected_keys)}")
            else:
                print("EfficientViT model state loaded with strict=False (no key mismatches)")
        except Exception as e2:
            raise RuntimeError(f"Both EfficientViT loading approaches failed: {e2}")

    model.eval()

    # Extract training information
    training_info = {
        'best_val_f1': float(checkpoint.get('best_f1', 0.0)),
        'best_val_loss': float(checkpoint.get('best_loss', float('inf'))),
        'best_val_accuracy': float(checkpoint.get('best_acc', 0.0)),
        'best_epoch': int(checkpoint.get('epoch', 0)) + 1,
        'model_checkpoint': EVALUATION_CONFIG_CASME2_EFFICIENTVIT['checkpoint_file'],
        'num_classes': EVALUATION_CONFIG_CASME2_EFFICIENTVIT['num_classes'],
        'efficientvit_variant': efficientvit_variant,
        'efficientvit_model': efficientvit_model_name,
        'config': checkpoint.get('casme2_efficientvit_config', {})
    }

    print(f"EfficientViT model loaded successfully:")
    print(f"  Best validation F1: {training_info['best_val_f1']:.4f}")
    print(f"  Best validation accuracy: {training_info['best_val_accuracy']:.4f}")
    print(f"  Best epoch: {training_info['best_epoch']}")
    print(f"  EfficientViT variant: {training_info['efficientvit_variant']}")
    print(f"  Model classes: {EVALUATION_CONFIG_CASME2_EFFICIENTVIT['num_classes']}")

    return model, training_info

def run_model_inference_casme2_efficientvit(model, test_loader, device):
    """Run CASME II EfficientViT model inference with cascaded group attention tracking"""
    print("Running CASME II EfficientViT model inference on test set...")

    model.eval()
    all_predictions = []
    all_probabilities = []
    all_labels = []
    all_sample_ids = []
    all_emotions = []
    all_subjects = []
    all_filenames = []

    inference_start = time.time()

    with torch.no_grad():
        for batch_idx, (images, labels, sample_ids, emotions, subjects, filenames) in enumerate(
            tqdm(test_loader, desc="CASME II EfficientViT Inference")):

            images = images.to(device)

            # Forward pass with robust EfficientViT TIMM output extraction
            try:
                outputs_raw = model(images)
                outputs = extract_logits_safe_casme2_efficientvit(outputs_raw)
            except Exception as e:
                print(f"Error in EfficientViT model forward pass: {e}")
                # Fallback: direct model call
                outputs = model(images)
                if not isinstance(outputs, torch.Tensor):
                    outputs = outputs[0] if isinstance(outputs, (list, tuple)) else outputs

            # Validate output shape for 7 CASME II classes
            if outputs.shape[1] != 7:
                print(f"Warning: Expected 7 classes output, got {outputs.shape[1]}")

            # Get probabilities and predictions
            probabilities = torch.softmax(outputs, dim=1)
            predictions = torch.argmax(probabilities, dim=1)

            # Store results (CPU for memory efficiency)
            all_predictions.extend(predictions.cpu().numpy())
            all_probabilities.extend(probabilities.cpu().numpy())
            all_labels.extend(labels.numpy())
            all_sample_ids.extend(sample_ids)
            all_emotions.extend(emotions)
            all_subjects.extend(subjects)
            all_filenames.extend(filenames)

    inference_time = time.time() - inference_start

    # Convert to arrays
    predictions_array = np.array(all_predictions)
    probabilities_array = np.array(all_probabilities)
    labels_array = np.array(all_labels)

    print(f"CASME II EfficientViT inference completed: {len(predictions_array)} samples in {inference_time:.2f}s")

    # Analyze prediction distribution
    unique_predictions, pred_counts = np.unique(predictions_array, return_counts=True)
    print(f"Predicted classes: {[CASME2_CLASSES[i] for i in unique_predictions]}")

    unique_labels, label_counts = np.unique(labels_array, return_counts=True)
    print(f"True classes in test: {[CASME2_CLASSES[i] for i in unique_labels]}")

    return {
        'predictions': predictions_array,
        'probabilities': probabilities_array,
        'labels': labels_array,
        'sample_ids': all_sample_ids,
        'emotions': all_emotions,
        'subjects': all_subjects,
        'filenames': all_filenames,
        'inference_time': inference_time,
        'samples_count': len(predictions_array)
    }

def analyze_wrong_predictions_casme2_efficientvit(inference_results):
    """Comprehensive wrong predictions analysis for CASME II EfficientViT"""
    print("Analyzing wrong predictions for CASME II EfficientViT micro-expression recognition...")

    predictions = inference_results['predictions']
    labels = inference_results['labels']
    sample_ids = inference_results['sample_ids']
    emotions = inference_results['emotions']
    subjects = inference_results['subjects']
    filenames = inference_results['filenames']

    # Find wrong predictions
    wrong_mask = predictions != labels
    wrong_indices = np.where(wrong_mask)[0]

    # Organize by true emotion class
    wrong_predictions_by_class = {}
    subject_error_analysis = {}

    for class_name in CASME2_CLASSES:
        wrong_predictions_by_class[class_name] = []

    # Analyze wrong predictions
    for idx in wrong_indices:
        true_label = labels[idx]
        pred_label = predictions[idx]
        sample_id = sample_ids[idx]
        emotion = emotions[idx]
        subject = subjects[idx]
        filename = filenames[idx]

        true_class = CASME2_CLASSES[true_label]
        pred_class = CASME2_CLASSES[pred_label]

        wrong_info = {
            'sample_id': sample_id,
            'filename': filename,
            'subject': subject,
            'true_label': int(true_label),
            'true_class': true_class,
            'predicted_label': int(pred_label),
            'predicted_class': pred_class,
            'emotion': emotion
        }

        wrong_predictions_by_class[true_class].append(wrong_info)

        # Subject error tracking
        if subject not in subject_error_analysis:
            subject_error_analysis[subject] = {'total': 0, 'wrong': 0, 'errors': []}
        subject_error_analysis[subject]['wrong'] += 1
        subject_error_analysis[subject]['errors'].append(wrong_info)

    # Count total samples per subject
    for subject in subjects:
        if subject in subject_error_analysis:
            subject_error_analysis[subject]['total'] += 1
        else:
            subject_error_analysis[subject] = {'total': 1, 'wrong': 0, 'errors': []}

    # Calculate error rates per subject
    for subject in subject_error_analysis:
        total = subject_error_analysis[subject]['total']
        wrong = subject_error_analysis[subject]['wrong']
        subject_error_analysis[subject]['error_rate'] = wrong / total if total > 0 else 0.0

    # Summary statistics
    total_wrong = len(wrong_indices)
    total_samples = len(predictions)
    error_rate = (total_wrong / total_samples) * 100

    # Confusion patterns analysis
    confusion_patterns = {}
    for idx in wrong_indices:
        true_label = labels[idx]
        pred_label = predictions[idx]
        pattern = f"{CASME2_CLASSES[true_label]}_to_{CASME2_CLASSES[pred_label]}"
        confusion_patterns[pattern] = confusion_patterns.get(pattern, 0) + 1

    analysis_results = {
        'analysis_metadata': {
            'evaluation_timestamp': datetime.now().strftime("%Y%m%d_%H%M%S"),
            'model_type': EVALUATION_CONFIG_CASME2_EFFICIENTVIT['model_type'],
            'dataset': EVALUATION_CONFIG_CASME2_EFFICIENTVIT['dataset_name'],
            'architecture': EVALUATION_CONFIG_CASME2_EFFICIENTVIT['architecture'],
            'total_samples': int(total_samples),
            'total_wrong_predictions': int(total_wrong),
            'overall_error_rate': float(error_rate)
        },
        'wrong_predictions_by_class': wrong_predictions_by_class,
        'subject_error_analysis': subject_error_analysis,
        'confusion_patterns': confusion_patterns,
        'error_summary': {
            class_name: len(wrong_predictions_by_class[class_name])
            for class_name in CASME2_CLASSES
        }
    }

    return analysis_results

def calculate_comprehensive_metrics_casme2_efficientvit(inference_results):
    """Calculate comprehensive evaluation metrics for CASME II EfficientViT micro-expression recognition"""
    print("Calculating comprehensive metrics for CASME II EfficientViT micro-expression recognition...")

    predictions = inference_results['predictions']
    probabilities = inference_results['probabilities']
    labels = inference_results['labels']

    if len(predictions) == 0:
        raise ValueError("No predictions to evaluate!")

    # Identify available classes in test set
    unique_test_labels = sorted(np.unique(labels))
    unique_predictions = sorted(np.unique(predictions))

    print(f"Test set contains labels: {[CASME2_CLASSES[i] for i in unique_test_labels]}")
    print(f"EfficientViT model predicted classes: {[CASME2_CLASSES[i] for i in unique_predictions]}")

    # Basic metrics
    accuracy = accuracy_score(labels, predictions)

    # Macro metrics (only for available classes)
    precision, recall, f1, support = precision_recall_fscore_support(
        labels, predictions, labels=unique_test_labels, average='macro', zero_division=0
    )

    print(f"Macro F1 (available classes): {f1:.4f}")

    # Per-class metrics (all 7 classes)
    precision_per_class, recall_per_class, f1_per_class, support_per_class = precision_recall_fscore_support(
        labels, predictions, labels=range(7), average=None, zero_division=0
    )

    # Confusion matrix
    cm = confusion_matrix(labels, predictions, labels=range(7))

    # Multi-class AUC (only for classes with test samples)
    auc_scores = {}
    fpr_dict = {}
    tpr_dict = {}

    try:
        labels_binarized = label_binarize(labels, classes=range(7))

        for i, class_name in enumerate(CASME2_CLASSES):
            if i in unique_test_labels and len(np.unique(labels_binarized[:, i])) > 1:
                fpr, tpr, _ = roc_curve(labels_binarized[:, i], probabilities[:, i])
                auc_score = auc(fpr, tpr)
                auc_scores[class_name] = float(auc_score)
                fpr_dict[class_name] = fpr.tolist()
                tpr_dict[class_name] = tpr.tolist()
            else:
                auc_scores[class_name] = 0.0
                fpr_dict[class_name] = [0.0, 1.0]
                tpr_dict[class_name] = [0.0, 0.0]

        # Macro AUC for available classes
        available_auc_scores = [auc_scores[CASME2_CLASSES[i]] for i in unique_test_labels]
        macro_auc = float(np.mean(available_auc_scores)) if available_auc_scores else 0.0

    except Exception as e:
        print(f"Warning: AUC calculation failed: {e}")
        auc_scores = {class_name: 0.0 for class_name in CASME2_CLASSES}
        macro_auc = 0.0

    # Subject-level analysis
    subjects = inference_results['subjects']
    subject_performance = {}

    for subject in set(subjects):
        subject_mask = [s == subject for s in subjects]
        subject_predictions = predictions[subject_mask]
        subject_labels = labels[subject_mask]

        if len(subject_predictions) > 0:
            subject_acc = accuracy_score(subject_labels, subject_predictions)
            subject_performance[subject] = {
                'accuracy': float(subject_acc),
                'samples': int(len(subject_predictions)),
                'correct': int(np.sum(subject_predictions == subject_labels))
            }

    # Comprehensive results
    comprehensive_results = {
        'evaluation_metadata': {
            'model_type': EVALUATION_CONFIG_CASME2_EFFICIENTVIT['model_type'],
            'dataset': EVALUATION_CONFIG_CASME2_EFFICIENTVIT['dataset_name'],
            'architecture': EVALUATION_CONFIG_CASME2_EFFICIENTVIT['architecture'],
            'evaluation_timestamp': datetime.now().strftime("%Y%m%d_%H%M%S"),
            'num_classes': EVALUATION_CONFIG_CASME2_EFFICIENTVIT['num_classes'],
            'class_names': EVALUATION_CONFIG_CASME2_EFFICIENTVIT['class_names'],
            'test_samples': int(len(labels)),
            'available_classes': [CASME2_CLASSES[i] for i in unique_test_labels],
            'missing_classes': [CASME2_CLASSES[i] for i in range(7) if i not in unique_test_labels]
        },

        'overall_performance': {
            'accuracy': float(accuracy),
            'macro_precision': float(precision),
            'macro_recall': float(recall),
            'macro_f1': float(f1),
            'macro_auc': macro_auc
        },

        'per_class_performance': {},

        'confusion_matrix': cm.tolist(),

        'subject_level_performance': subject_performance,

        'roc_analysis': {
            'auc_scores': auc_scores,
            'fpr_curves': fpr_dict,
            'tpr_curves': tpr_dict
        },

        'inference_performance': {
            'total_time_seconds': float(inference_results['inference_time']),
            'average_time_ms_per_sample': float(inference_results['inference_time'] * 1000 / len(labels))
        }
    }

    # Per-class performance details
    for i, class_name in enumerate(CASME2_CLASSES):
        comprehensive_results['per_class_performance'][class_name] = {
            'precision': float(precision_per_class[i]),
            'recall': float(recall_per_class[i]),
            'f1_score': float(f1_per_class[i]),
            'support': int(support_per_class[i]),
            'auc': auc_scores[class_name],
            'in_test_set': i in unique_test_labels
        }

    return comprehensive_results

def save_evaluation_results_casme2_efficientvit(evaluation_results, wrong_predictions_results, results_dir):
    """Save comprehensive evaluation results for CASME II EfficientViT"""
    os.makedirs(results_dir, exist_ok=True)

    # Save main evaluation results
    results_file = f"{results_dir}/casme2_efficientvit_direct_evaluation_results.json"
    with open(results_file, 'w') as f:
        json.dump(evaluation_results, f, indent=2, default=str)

    # Save wrong predictions analysis
    wrong_predictions_file = f"{results_dir}/casme2_efficientvit_direct_wrong_predictions.json"
    with open(wrong_predictions_file, 'w') as f:
        json.dump(wrong_predictions_results, f, indent=2, default=str)

    print(f"EfficientViT evaluation results saved:")
    print(f"  Main results: {results_file}")
    print(f"  Wrong predictions: {wrong_predictions_file}")

    return results_file, wrong_predictions_file

# Main evaluation execution for EfficientViT
try:
    print("Starting CASME II EfficientViT Direct Baseline comprehensive evaluation...")

    # Create test dataset
    print("Creating CASME II test dataset for EfficientViT...")
    casme2_test_dataset = CASME2DatasetEvaluationEfficientViT(
        split_metadata=GLOBAL_CONFIG_CASME2['metadata'],
        dataset_root=GLOBAL_CONFIG_CASME2['test_path'].replace('/test', ''),
        transform=GLOBAL_CONFIG_CASME2['transform_val'],
        split='test',
        use_ram_cache=True
    )

    if len(casme2_test_dataset) == 0:
        raise ValueError("No test samples found! Check test data path.")

    casme2_test_loader = DataLoader(
        casme2_test_dataset,
        batch_size=CASME2_EFFICIENTVIT_CONFIG['batch_size'],
        shuffle=False,
        num_workers=CASME2_EFFICIENTVIT_CONFIG['num_workers'],
        pin_memory=True
    )

    # Load trained EfficientViT model
    checkpoint_path = f"{GLOBAL_CONFIG_CASME2['checkpoint_root']}/{EVALUATION_CONFIG_CASME2_EFFICIENTVIT['checkpoint_file']}"
    casme2_efficientvit_model, training_info = load_trained_model_casme2_efficientvit(checkpoint_path, GLOBAL_CONFIG_CASME2['device'])

    # Run EfficientViT inference
    inference_results = run_model_inference_casme2_efficientvit(casme2_efficientvit_model, casme2_test_loader, GLOBAL_CONFIG_CASME2['device'])

    # Calculate comprehensive metrics
    evaluation_results = calculate_comprehensive_metrics_casme2_efficientvit(inference_results)

    # Analyze wrong predictions
    wrong_predictions_results = analyze_wrong_predictions_casme2_efficientvit(inference_results)

    # Add training information
    evaluation_results['training_information'] = training_info

    # Save results
    results_dir = f"{GLOBAL_CONFIG_CASME2['results_root']}/evaluation_results"
    results_file, wrong_file = save_evaluation_results_casme2_efficientvit(
        evaluation_results, wrong_predictions_results, results_dir
    )

    # Display comprehensive results
    print("\n" + "=" * 60)
    print("CASME II EFFICIENTVIT DIRECT BASELINE EVALUATION RESULTS")
    print("=" * 60)

    # Overall performance
    overall = evaluation_results['overall_performance']
    print(f"Overall Performance (Macro - Available Classes):")
    print(f"  Accuracy:  {overall['accuracy']:.4f}")
    print(f"  Precision: {overall['macro_precision']:.4f}")
    print(f"  Recall:    {overall['macro_recall']:.4f}")
    print(f"  F1 Score:  {overall['macro_f1']:.4f}")
    print(f"  AUC:       {overall['macro_auc']:.4f}")

    # Per-class performance
    print(f"\nPer-Class Performance:")
    for class_name, metrics in evaluation_results['per_class_performance'].items():
        in_test = "Present" if metrics['in_test_set'] else "Missing"
        print(f"  {class_name} [{in_test}]: F1={metrics['f1_score']:.4f}, "
              f"AUC={metrics['auc']:.4f}, Support={metrics['support']}")

    # Training vs test comparison
    print(f"\nTraining vs Test Performance:")
    training_f1 = training_info['best_val_f1']
    training_acc = training_info['best_val_accuracy']
    test_f1 = overall['macro_f1']
    test_acc = overall['accuracy']

    print(f"  Training Val F1:  {training_f1:.4f}")
    print(f"  Test F1:          {test_f1:.4f}")
    print(f"  F1 Difference:    {training_f1 - test_f1:+.4f}")
    print(f"  Training Val Acc: {training_acc:.4f}")
    print(f"  Test Accuracy:    {test_acc:.4f}")
    print(f"  Acc Difference:   {training_acc - test_acc:+.4f}")
    print(f"  Best Epoch:       {training_info['best_epoch']}")
    print(f"  EfficientViT Variant: {training_info['efficientvit_variant']}")

    # Wrong predictions summary
    print(f"\n" + "=" * 40)
    print("WRONG PREDICTIONS ANALYSIS")
    print("=" * 40)

    wrong_meta = wrong_predictions_results['analysis_metadata']
    print(f"Total wrong predictions: {wrong_meta['total_wrong_predictions']} / {wrong_meta['total_samples']}")
    print(f"Overall error rate: {wrong_meta['overall_error_rate']:.2f}%")

    print(f"\nErrors by True Class:")
    for class_name, error_count in wrong_predictions_results['error_summary'].items():
        if error_count > 0:
            wrong_samples = wrong_predictions_results['wrong_predictions_by_class'][class_name]
            print(f"  {class_name}: {error_count} errors")
            for sample in wrong_samples[:3]:  # Show first 3
                print(f"    - {sample['filename']} -> predicted as {sample['predicted_class']}")
            if len(wrong_samples) > 3:
                print(f"    ... and {len(wrong_samples) - 3} more")

    # Subject-level analysis
    print(f"\nSubject-Level Performance:")
    subject_perfs = list(evaluation_results['subject_level_performance'].items())
    subject_perfs.sort(key=lambda x: x[1]['accuracy'], reverse=True)
    for subject, perf in subject_perfs[:5]:  # Show top 5
        print(f"  {subject}: {perf['accuracy']:.3f} ({perf['correct']}/{perf['samples']})")

    # Most common confusion patterns
    print(f"\nMost Common Confusion Patterns:")
    patterns = sorted(wrong_predictions_results['confusion_patterns'].items(),
                     key=lambda x: x[1], reverse=True)
    for pattern, count in patterns[:3]:
        print(f"  {pattern}: {count} cases")

    print(f"\nInference Performance:")
    print(f"  Total time: {inference_results['inference_time']:.2f}s")
    print(f"  Speed: {evaluation_results['inference_performance']['average_time_ms_per_sample']:.1f} ms/sample")

    print(f"\nMissing Classes: {evaluation_results['evaluation_metadata']['missing_classes']}")

    print("\n" + "=" * 60)
    print("CASME II EFFICIENTVIT DIRECT BASELINE EVALUATION COMPLETED")
    print("=" * 60)

except Exception as e:
    print(f"EfficientViT evaluation failed: {e}")
    import traceback
    traceback.print_exc()

finally:
    # Memory cleanup
    if torch.cuda.is_available():
        torch.cuda.synchronize()
        torch.cuda.empty_cache()

print("Next: Cell 4 - EfficientViT Confusion Matrix Analysis and Visualization")
# Out:
# CASME II EfficientViT Direct Baseline Evaluation Framework
# ============================================================
# Model: EfficientViT_CASME2_Direct_Baseline
# Task: micro_expression_recognition
# Classes: ['others', 'disgust', 'happiness', 'repression', 'surprise', 'sadness', 'fear']
# Input size: 384x384
# Architecture: efficientvit_cascaded_group_attention
# Starting CASME II EfficientViT Direct Baseline comprehensive evaluation...
# Creating CASME II test dataset for EfficientViT...
# Loading CASME II test dataset for EfficientViT evaluation...
# Loaded 28 CASME II test samples for EfficientViT evaluation
# Test set class distribution:
#   others: 10 samples (35.7%)
#   disgust: 7 samples (25.0%)
#   happiness: 4 samples (14.3%)
#   repression: 3 samples (10.7%)
#   surprise: 3 samples (10.7%)
#   sadness: 1 samples (3.6%)
# Test set covers 16 subjects
# Missing classes in test set: ['fear']
# Preloading 28 test images to RAM for EfficientViT evaluation...
# Loading test images: 100%|██████████| 28/28 [00:45<00:00,  1.63s/it]
# Test RAM caching completed: 28 valid images, ~0.05GB
# Loading trained CASME II EfficientViT model from: /content/drive/MyDrive/RESEARCH-WORKSPACE/ACTIVE-PROJECTS/Thesis_MER_Project/models/02_03_efficientvit_direct/casme2_efficientvit_direct_best_f1.pth
# EfficientViT checkpoint loaded using: standard
# Detected EfficientViT variant: m5
# Detected EfficientViT model: efficientvit_m5.r224_in1k
# Loading TIMM EfficientViT with original head...
# EfficientViT feature dimension (extracted): 384
# Expected embed dimensions: [192, 288, 384]
# EfficientViT CASME II: 384 -> CGA -> 512 -> 128 -> 7
# Model parameters: Total=12.4M, Trainable=12.4M
# EfficientViT model state loaded with strict=True
# EfficientViT model loaded successfully:
#   Best validation F1: 0.1352
#   Best validation accuracy: 0.2308
#   Best epoch: 27
#   EfficientViT variant: m5
#   Model classes: 7
# Running CASME II EfficientViT model inference on test set...
# CASME II EfficientViT Inference: 100%|██████████| 2/2 [00:06<00:00,  3.16s/it]
# CASME II EfficientViT inference completed: 28 samples in 6.32s
# Predicted classes: ['others', 'disgust', 'happiness', 'repression', 'surprise']
# True classes in test: ['others', 'disgust', 'happiness', 'repression', 'surprise', 'sadness']
# Calculating comprehensive metrics for CASME II EfficientViT micro-expression recognition...
# Test set contains labels: ['others', 'disgust', 'happiness', 'repression', 'surprise', 'sadness']
# EfficientViT model predicted classes: ['others', 'disgust', 'happiness', 'repression', 'surprise']
# Macro F1 (available classes): 0.1536
# Analyzing wrong predictions for CASME II EfficientViT micro-expression recognition...
# EfficientViT evaluation results saved:
#   Main results: /content/drive/MyDrive/RESEARCH-WORKSPACE/ACTIVE-PROJECTS/Thesis_MER_Project/results/02_03_efficientvit_direct/evaluation_results/casme2_efficientvit_direct_evaluation_results.json
#   Wrong predictions: /content/drive/MyDrive/RESEARCH-WORKSPACE/ACTIVE-PROJECTS/Thesis_MER_Project/results/02_03_efficientvit_direct/evaluation_results/casme2_efficientvit_direct_wrong_predictions.json
#
# ============================================================
# CASME II EFFICIENTVIT DIRECT BASELINE EVALUATION RESULTS
# ============================================================
# Overall Performance (Macro - Available Classes):
#   Accuracy:  0.1786
#   Precision: 0.1583
#   Recall:    0.2004
#   F1 Score:  0.1536
#   AUC:       0.6465
#
# Per-Class Performance:
#   others [Present]: F1=0.0000, AUC=0.6111, Support=10
#   disgust [Present]: F1=0.3636, AUC=0.7007, Support=7
#   happiness [Present]: F1=0.2500, AUC=0.6875, Support=4
#   repression [Present]: F1=0.0000, AUC=0.4800, Support=3
#   surprise [Present]: F1=0.3077, AUC=0.7333, Support=3
#   sadness [Present]: F1=0.0000, AUC=0.6667, Support=1
#   fear [Missing]: F1=0.0000, AUC=0.0000, Support=0
#
# Training vs Test Performance:
#   Training Val F1:  0.1352
#   Test F1:          0.1536
#   F1 Difference:    -0.0184
#   Training Val Acc: 0.2308
#   Test Accuracy:    0.1786
#   Acc Difference:   +0.0522
#   Best Epoch:       27
#   EfficientViT Variant: m5
#
# ========================================
# WRONG PREDICTIONS ANALYSIS
# ========================================
# Total wrong predictions: 23 / 28
# Overall error rate: 82.14%
#
# Errors by True Class:
#   others: 10 errors
#     - sub14_EP04_04f_others.jpg -> predicted as surprise
#     - sub04_EP13_02f_others.jpg -> predicted as surprise
#     - sub01_EP19_01_others.jpg -> predicted as repression
#     ... and 7 more
#   disgust: 5 errors
#     - sub05_EP09_05f_disgust.jpg -> predicted as others
#     - sub26_EP18_49_disgust.jpg -> predicted as repression
#     - sub26_EP18_50_disgust.jpg -> predicted as happiness
#     ... and 2 more
#   happiness: 3 errors
#     - sub14_EP09_06_happiness.jpg -> predicted as surprise
#     - sub12_EP03_04_happiness.jpg -> predicted as repression
#     - sub17_EP06_07_happiness.jpg -> predicted as surprise
#   repression: 3 errors
#     - sub09_EP09_05_repression.jpg -> predicted as disgust
#     - sub17_EP05_03f_repression.jpg -> predicted as happiness
#     - sub16_EP01_08_repression.jpg -> predicted as surprise
#   surprise: 1 errors
#     - sub12_EP02_05_surprise.jpg -> predicted as repression
#   sadness: 1 errors
#     - sub17_EP15_03_sadness.jpg -> predicted as others
#
# Subject-Level Performance:
#   sub02: 1.000 (1/1)
#   sub23: 0.500 (1/2)
#   sub17: 0.400 (2/5)
#   sub26: 0.333 (1/3)
#   sub09: 0.000 (0/1)
#
# Most Common Confusion Patterns:
#   others_to_surprise: 4 cases
#   others_to_repression: 4 cases
#   disgust_to_others: 2 cases
#
# Inference Performance:
#   Total time: 6.32s
#   Speed: 225.7 ms/sample
#
# Missing Classes: ['fear']
#
# ============================================================
# CASME II EFFICIENTVIT DIRECT BASELINE EVALUATION COMPLETED
# ============================================================
# Next: Cell 4 - EfficientViT Confusion Matrix Analysis and Visualization

# %%
# @title Cell 4: CASME II EfficientViT Direct Baseline Confusion Matrix Generation

# File: 02_03_EfficientViT_Direct_Baseline_Cell4.py
# Location: experiments/02_03_EfficientViT_Direct_Baseline.ipynb
# Purpose: Generate professional confusion matrix and comprehensive analysis for CASME II EfficientViT micro-expression recognition
# Dependencies: Trained model evaluation results from Cell 3

import json
import os
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
import seaborn as sns
from datetime import datetime

print("CASME II EfficientViT Direct Baseline Confusion Matrix Generation")
print("=" * 65)

# Project paths configuration - EfficientViT specific
PROJECT_ROOT = "/content/drive/MyDrive/RESEARCH-WORKSPACE/ACTIVE-PROJECTS/Thesis_MER_Project"
RESULTS_ROOT = f"{PROJECT_ROOT}/results/02_03_efficientvit_direct"

def find_evaluation_json_files_casme2_efficientvit(results_path):
    """Find CASME II EfficientViT evaluation JSON files"""
    json_files = {}

    eval_dir = f"{results_path}/evaluation_results"

    if os.path.exists(eval_dir):
        # Look for main EfficientViT evaluation results
        eval_files = glob.glob(f"{eval_dir}/casme2_efficientvit_direct_evaluation_results.json")
        if eval_files:
            json_files['main'] = eval_files[0]
            print(f"Found CASME II EfficientViT evaluation file: {os.path.basename(eval_files[0])}")

        # Look for EfficientViT wrong predictions analysis
        wrong_files = glob.glob(f"{eval_dir}/casme2_efficientvit_direct_wrong_predictions.json")
        if wrong_files:
            json_files['wrong_predictions'] = wrong_files[0]
            print(f"Found EfficientViT wrong predictions file: {os.path.basename(wrong_files[0])}")

        if not json_files:
            print(f"WARNING: No EfficientViT evaluation results found in {eval_dir}")
            print("Make sure Cell 3 (EfficientViT evaluation) has been executed first!")
    else:
        print(f"ERROR: EfficientViT evaluation directory not found: {eval_dir}")

    return json_files

def load_evaluation_results_casme2_efficientvit(json_path):
    """Load and parse CASME II EfficientViT evaluation results JSON"""
    try:
        with open(json_path, 'r') as f:
            data = json.load(f)
        print(f"Successfully loaded EfficientViT evaluation results from: {os.path.basename(json_path)}")
        return data
    except Exception as e:
        print(f"ERROR loading {json_path}: {str(e)}")
        return None

def calculate_weighted_f1_casme2_efficientvit(per_class_performance):
    """Calculate weighted F1 score for CASME II EfficientViT micro-expression classes"""
    # Only count classes that have test samples (support > 0)
    total_support = sum([class_data['support'] for class_data in per_class_performance.values()
                        if class_data['support'] > 0])

    if total_support == 0:
        return 0.0

    weighted_f1 = 0.0

    for class_name, class_data in per_class_performance.items():
        if class_data['support'] > 0:  # Only include classes with test samples
            weight = class_data['support'] / total_support
            weighted_f1 += class_data['f1_score'] * weight

    return weighted_f1

def calculate_balanced_accuracy_casme2_efficientvit(confusion_matrix):
    """
    Calculate balanced accuracy for CASME II EfficientViT 7-class micro-expression recognition
    Handles classes with zero support (missing in test set)
    """
    cm = np.array(confusion_matrix)
    n_classes = cm.shape[0]

    per_class_balanced_acc = []

    # Find classes with actual test samples
    classes_with_samples = []
    for i in range(n_classes):
        if cm[i, :].sum() > 0:  # Class has test samples
            classes_with_samples.append(i)

    for i in classes_with_samples:
        # True positives, false negatives, false positives, true negatives for class i
        tp = cm[i, i]
        fn = cm[i, :].sum() - tp  # Sum of row i minus diagonal
        fp = cm[:, i].sum() - tp  # Sum of column i minus diagonal
        tn = cm.sum() - tp - fn - fp  # Total minus TP, FN, FP

        # Calculate sensitivity and specificity for class i
        sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0.0
        specificity = tn / (tn + fp) if (tn + fp) > 0 else 0.0

        # Per-class balanced accuracy
        class_balanced_acc = (sensitivity + specificity) / 2
        per_class_balanced_acc.append(class_balanced_acc)

    # Overall balanced accuracy (mean of available classes)
    balanced_acc = np.mean(per_class_balanced_acc) if per_class_balanced_acc else 0.0

    return balanced_acc

def determine_text_color_casme2_efficientvit(color_value, threshold=0.5):
    """Determine optimal text color based on background intensity"""
    return 'white' if color_value > threshold else 'black'

def analyze_missing_classes_casme2_efficientvit(data):
    """Analyze missing classes in CASME II EfficientViT test set"""
    meta = data['evaluation_metadata']
    available_classes = meta.get('available_classes', [])
    missing_classes = meta.get('missing_classes', [])
    efficientvit_variant = data.get('training_information', {}).get('efficientvit_variant', 'unknown')

    print(f"EfficientViT Class Analysis:")
    print(f"  Variant: {efficientvit_variant}")
    print(f"  Available in test: {available_classes}")
    print(f"  Missing from test: {missing_classes}")

    return {
        'available': available_classes,
        'missing': missing_classes,
        'total_classes': len(meta['class_names']),
        'efficientvit_variant': efficientvit_variant
    }

def create_confusion_matrix_plot_casme2_efficientvit(data, output_path):
    """Create professional confusion matrix visualization for CASME II EfficientViT micro-expression recognition"""

    # Extract data
    meta = data['evaluation_metadata']
    class_names = meta['class_names']
    cm = np.array(data['confusion_matrix'], dtype=int)
    overall = data['overall_performance']
    per_class = data['per_class_performance']
    training_info = data.get('training_information', {})
    efficientvit_variant = training_info.get('efficientvit_variant', 'unknown')

    print(f"Processing EfficientViT confusion matrix for CASME II classes: {class_names}")
    print(f"EfficientViT variant: {efficientvit_variant}")
    print(f"Confusion matrix shape: {cm.shape}")

    # Calculate comprehensive metrics
    macro_f1 = overall.get('macro_f1', 0.0)
    accuracy = overall.get('accuracy', 0.0)
    weighted_f1 = calculate_weighted_f1_casme2_efficientvit(per_class)
    balanced_acc = calculate_balanced_accuracy_casme2_efficientvit(cm)

    print(f"Calculated metrics - Macro F1: {macro_f1:.4f}, Weighted F1: {weighted_f1:.4f}, "
          f"Balanced Acc: {balanced_acc:.4f}, Accuracy: {accuracy:.4f}")

    # Row-wise normalization for percentage display
    row_sums = cm.sum(axis=1, keepdims=True)
    with np.errstate(divide='ignore', invalid='ignore'):
        cm_pct = np.divide(cm, row_sums, where=(row_sums!=0))
        cm_pct = np.nan_to_num(cm_pct)

    # Create visualization with appropriate size for 7 classes
    fig, ax = plt.subplots(figsize=(12, 10))

    # Color scheme optimized for EfficientViT micro-expression research
    cmap = 'Blues'

    # Create heatmap with improved color scaling
    im = ax.imshow(cm_pct, interpolation='nearest', cmap=cmap, vmin=0.0, vmax=0.8)

    # Add colorbar
    cbar = plt.colorbar(im, ax=ax, fraction=0.046, pad=0.04)
    cbar.set_label('True Class Percentage', rotation=270, labelpad=15, fontsize=11)

    # Annotate cells with count and percentage
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            count = cm[i, j]

            # Handle percentage calculation for classes with 0 samples
            if row_sums[i, 0] > 0:
                percentage = cm_pct[i, j] * 100
                text = f"{count}\n{percentage:.1f}%"
            else:
                text = f"{count}\n(N/A)"  # Class has no test samples

            # Determine text color based on cell intensity
            cell_value = cm_pct[i, j]
            text_color = determine_text_color_casme2_efficientvit(cell_value, threshold=0.4)

            ax.text(j, i, text, ha="center", va="center",
                   color=text_color, fontsize=9, fontweight='bold')

    # Configure axes with micro-expression class names
    ax.set_xticks(np.arange(len(class_names)))
    ax.set_yticks(np.arange(len(class_names)))
    ax.set_xticklabels(class_names, rotation=45, ha='right', fontsize=10)
    ax.set_yticklabels(class_names, fontsize=10)
    ax.set_xlabel("Predicted Label", fontsize=12, fontweight='bold')
    ax.set_ylabel("True Label", fontsize=12, fontweight='bold')

    # Add note about missing classes and EfficientViT architecture
    missing_classes = meta.get('missing_classes', [])
    note_lines = []
    if missing_classes:
        note_lines.append(f"Missing classes: {', '.join(missing_classes)}")
    note_lines.append(f"EfficientViT-{efficientvit_variant.upper()} | Cascaded Group Attention")

    if note_lines:
        note_text = "\n".join(note_lines)
        ax.text(0.02, 0.98, note_text, transform=ax.transAxes, fontsize=9,
                verticalalignment='top', bbox=dict(boxstyle='round', facecolor='lightyellow', alpha=0.8))

    # Create comprehensive title for EfficientViT micro-expression research
    title = f"CASME II EfficientViT ({efficientvit_variant.upper()}) Micro-Expression Recognition\n"
    title += f"Acc: {accuracy:.4f}  |  Macro F1: {macro_f1:.4f}  |  Weighted F1: {weighted_f1:.4f}  |  Balanced Acc: {balanced_acc:.4f}"
    ax.set_title(title, fontsize=12, pad=25, fontweight='bold')

    # Adjust layout and save
    plt.tight_layout()
    plt.savefig(output_path, dpi=300, bbox_inches='tight', facecolor='white')
    plt.close(fig)

    print(f"EfficientViT confusion matrix saved to: {os.path.basename(output_path)}")

    return {
        'accuracy': accuracy,
        'macro_f1': macro_f1,
        'weighted_f1': weighted_f1,
        'balanced_accuracy': balanced_acc,
        'missing_classes': missing_classes,
        'efficientvit_variant': efficientvit_variant
    }

def create_per_class_performance_chart_casme2_efficientvit(data, output_path):
    """Create per-class performance visualization for CASME II EfficientViT"""
    per_class = data['per_class_performance']
    class_names = data['evaluation_metadata']['class_names']
    training_info = data.get('training_information', {})
    efficientvit_variant = training_info.get('efficientvit_variant', 'unknown')

    # Extract metrics for each class
    classes = []
    f1_scores = []
    precisions = []
    recalls = []
    supports = []
    in_test_flags = []

    for class_name in class_names:
        class_data = per_class[class_name]
        classes.append(class_name)
        f1_scores.append(class_data['f1_score'])
        precisions.append(class_data['precision'])
        recalls.append(class_data['recall'])
        supports.append(class_data['support'])
        in_test_flags.append(class_data['in_test_set'])

    # Create grouped bar chart
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 10))

    x = np.arange(len(classes))
    width = 0.25

    # Top plot: F1, Precision, Recall
    bars1 = ax1.bar(x - width, f1_scores, width, label='F1 Score', alpha=0.8, color='steelblue')
    bars2 = ax1.bar(x, precisions, width, label='Precision', alpha=0.8, color='orange')
    bars3 = ax1.bar(x + width, recalls, width, label='Recall', alpha=0.8, color='green')

    ax1.set_xlabel('Emotion Classes', fontweight='bold')
    ax1.set_ylabel('Score', fontweight='bold')
    ax1.set_title(f'CASME II EfficientViT ({efficientvit_variant.upper()}) Per-Class Performance Metrics',
                 fontweight='bold', pad=20)
    ax1.set_xticks(x)
    ax1.set_xticklabels(classes, rotation=45, ha='right')
    ax1.legend()
    ax1.grid(axis='y', alpha=0.3)
    ax1.set_ylim(0, 1.0)

    # Add value labels on bars
    for bars in [bars1, bars2, bars3]:
        for bar, in_test in zip(bars, in_test_flags):
            height = bar.get_height()
            if in_test:
                ax1.annotate(f'{height:.3f}', xy=(bar.get_x() + bar.get_width() / 2, height),
                           xytext=(0, 3), textcoords="offset points", ha='center', va='bottom', fontsize=8)
            else:
                # Mark missing classes
                ax1.annotate('N/A', xy=(bar.get_x() + bar.get_width() / 2, height),
                           xytext=(0, 3), textcoords="offset points", ha='center', va='bottom',
                           fontsize=8, color='red', fontweight='bold')

    # Bottom plot: Support (sample count)
    bars4 = ax2.bar(x, supports, color='purple', alpha=0.7)
    ax2.set_xlabel('Emotion Classes', fontweight='bold')
    ax2.set_ylabel('Number of Test Samples', fontweight='bold')
    ax2.set_title('CASME II Test Set Class Distribution (EfficientViT)', fontweight='bold')
    ax2.set_xticks(x)
    ax2.set_xticklabels(classes, rotation=45, ha='right')
    ax2.grid(axis='y', alpha=0.3)

    # Add value labels on support bars
    for bar, support in zip(bars4, supports):
        height = bar.get_height()
        ax2.annotate(f'{int(support)}', xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3), textcoords="offset points", ha='center', va='bottom', fontsize=10)

    # Add architecture note
    fig.text(0.02, 0.02, f"Architecture: EfficientViT-{efficientvit_variant.upper()} Cascaded Group Attention",
             fontsize=9, style='italic', alpha=0.7)

    plt.tight_layout()
    plt.savefig(output_path, dpi=300, bbox_inches='tight', facecolor='white')
    plt.close(fig)

    print(f"EfficientViT per-class performance chart saved to: {os.path.basename(output_path)}")

def generate_performance_summary_casme2_efficientvit(evaluation_data, wrong_predictions_data=None):
    """Generate comprehensive performance summary for CASME II EfficientViT"""

    print("\n" + "=" * 65)
    print("CASME II EFFICIENTVIT MICRO-EXPRESSION RECOGNITION PERFORMANCE SUMMARY")
    print("=" * 65)

    # Overall performance
    overall = evaluation_data['overall_performance']
    meta = evaluation_data['evaluation_metadata']
    training_info = evaluation_data.get('training_information', {})
    efficientvit_variant = training_info.get('efficientvit_variant', 'unknown')

    print(f"Dataset: {meta['dataset']}")
    print(f"Test samples: {meta['test_samples']}")
    print(f"Model: {meta['model_type']}")
    print(f"Architecture: EfficientViT-{efficientvit_variant.upper()} Cascaded Group Attention")
    print(f"Evaluation date: {meta['evaluation_timestamp']}")

    print(f"\nOverall Performance:")
    print(f"  Accuracy:         {overall['accuracy']:.4f}")
    print(f"  Macro Precision:  {overall['macro_precision']:.4f}")
    print(f"  Macro Recall:     {overall['macro_recall']:.4f}")
    print(f"  Macro F1:         {overall['macro_f1']:.4f}")
    print(f"  Macro AUC:        {overall['macro_auc']:.4f}")

    # Per-class performance
    print(f"\nPer-Class Performance:")
    per_class = evaluation_data['per_class_performance']

    print(f"{'Class':<12} {'F1':<8} {'Precision':<10} {'Recall':<8} {'AUC':<8} {'Support':<8} {'In Test'}")
    print("-" * 65)

    for class_name, metrics in per_class.items():
        in_test = "Yes" if metrics['in_test_set'] else "No"
        print(f"{class_name:<12} {metrics['f1_score']:<8.4f} {metrics['precision']:<10.4f} "
              f"{metrics['recall']:<8.4f} {metrics['auc']:<8.4f} {metrics['support']:<8} {in_test}")

    # Training vs test performance
    if 'training_information' in evaluation_data:
        training = evaluation_data['training_information']
        print(f"\nTraining vs Test Comparison:")
        print(f"  Training Val F1:  {training['best_val_f1']:.4f}")
        print(f"  Test F1:          {overall['macro_f1']:.4f}")
        print(f"  Performance Gap:  {training['best_val_f1'] - overall['macro_f1']:+.4f}")
        print(f"  Best Epoch:       {training['best_epoch']}")
        print(f"  EfficientViT Variant: {training['efficientvit_variant']}")

    # Class imbalance analysis
    missing_classes = meta.get('missing_classes', [])
    available_classes = meta.get('available_classes', [])

    print(f"\nClass Availability Analysis:")
    print(f"  Available classes: {len(available_classes)}/7")
    print(f"  Missing classes: {missing_classes if missing_classes else 'None'}")

    # Architecture-specific information
    print(f"\nEfficientViT Architecture Details:")
    print(f"  Variant: {efficientvit_variant}")
    print(f"  Cascaded Group Attention: Memory efficient multi-head processing")
    print(f"  Sandwich Layout: FFN-MHSA-FFN for improved efficiency")
    print(f"  Attention Diversity: Different feature splits for each head")

    # Wrong predictions summary if available
    if wrong_predictions_data:
        wrong_meta = wrong_predictions_data['analysis_metadata']
        print(f"\nError Analysis:")
        print(f"  Total errors: {wrong_meta['total_wrong_predictions']}/{wrong_meta['total_samples']}")
        print(f"  Error rate: {wrong_meta['overall_error_rate']:.2f}%")

        # Top confusion patterns
        patterns = wrong_predictions_data.get('confusion_patterns', {})
        if patterns:
            print(f"\nTop Confusion Patterns:")
            sorted_patterns = sorted(patterns.items(), key=lambda x: x[1], reverse=True)[:3]
            for pattern, count in sorted_patterns:
                print(f"  {pattern}: {count} cases")

    print(f"\nInference Performance:")
    inference = evaluation_data['inference_performance']
    print(f"  Total time: {inference['total_time_seconds']:.2f}s")
    print(f"  Speed: {inference['average_time_ms_per_sample']:.1f} ms/sample")

# Find EfficientViT evaluation JSON files
json_files = find_evaluation_json_files_casme2_efficientvit(RESULTS_ROOT)

if not json_files:
    print(f"ERROR: No EfficientViT evaluation JSON files found in {RESULTS_ROOT}")
    print("Make sure Cell 3 (EfficientViT evaluation) has been executed first!")
else:
    print(f"Found {len(json_files)} EfficientViT evaluation file(s)")

# Create output directory - Fixed path as requested
output_dir = f"{RESULTS_ROOT}/confusion_matrix_analysis"
Path(output_dir).mkdir(parents=True, exist_ok=True)

# Process EfficientViT evaluation results
results_summary = {}
generated_files = []

if 'main' in json_files:
    # Load main evaluation data
    eval_data = load_evaluation_results_casme2_efficientvit(json_files['main'])

    # Load wrong predictions data if available
    wrong_data = None
    if 'wrong_predictions' in json_files:
        wrong_data = load_evaluation_results_casme2_efficientvit(json_files['wrong_predictions'])

    if eval_data is not None:
        try:
            # Analyze missing classes for EfficientViT
            class_analysis = analyze_missing_classes_casme2_efficientvit(eval_data)

            # Generate EfficientViT confusion matrix
            cm_output_path = os.path.join(output_dir, "confusion_matrix_CASME2_EfficientViT_Direct.png")
            metrics = create_confusion_matrix_plot_casme2_efficientvit(eval_data, cm_output_path)
            generated_files.append(cm_output_path)

            # Generate EfficientViT per-class performance chart
            perf_output_path = os.path.join(output_dir, "per_class_performance_CASME2_EfficientViT_Direct.png")
            create_per_class_performance_chart_casme2_efficientvit(eval_data, perf_output_path)
            generated_files.append(perf_output_path)

            results_summary['casme2_efficientvit'] = metrics
            results_summary['casme2_efficientvit']['class_analysis'] = class_analysis

            print(f"SUCCESS: EfficientViT visualization files generated successfully")

        except Exception as e:
            print(f"ERROR: Failed to generate EfficientViT visualizations: {str(e)}")
            import traceback
            traceback.print_exc()

        # Generate comprehensive EfficientViT summary
        generate_performance_summary_casme2_efficientvit(eval_data, wrong_data)

    else:
        print("ERROR: Could not load EfficientViT evaluation data")
else:
    print("ERROR: No main EfficientViT evaluation results found")

# Final summary
if generated_files:
    print(f"\n" + "=" * 65)
    print("CASME II EFFICIENTVIT CONFUSION MATRIX GENERATION COMPLETED")
    print("=" * 65)

    print(f"Generated visualization files:")
    for file_path in generated_files:
        filename = os.path.basename(file_path)
        print(f"  {filename}")

    if 'casme2_efficientvit' in results_summary:
        casme2_efficientvit = results_summary['casme2_efficientvit']
        print(f"\nFinal Performance Summary:")
        print(f"  Architecture:     EfficientViT-{casme2_efficientvit['efficientvit_variant'].upper()}")
        print(f"  Accuracy:         {casme2_efficientvit['accuracy']:.4f}")
        print(f"  Macro F1:         {casme2_efficientvit['macro_f1']:.4f}")
        print(f"  Weighted F1:      {casme2_efficientvit['weighted_f1']:.4f}")
        print(f"  Balanced Acc:     {casme2_efficientvit['balanced_accuracy']:.4f}")

        if 'class_analysis' in casme2_efficientvit:
            analysis = casme2_efficientvit['class_analysis']
            print(f"  Available classes: {len(analysis['available'])}/{analysis['total_classes']}")
            print(f"  Missing classes: {len(analysis['missing'])}")

    print(f"\nFiles saved in: {output_dir}")
    print(f"Analysis completed at: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

else:
    print(f"\nERROR: No EfficientViT visualizations were generated")
    print("Please check:")
    print("1. Cell 3 EfficientViT evaluation results exist")
    print("2. JSON file structure is correct")
    print("3. No file permission issues")

print("\nCell 4 completed - CASME II EfficientViT confusion matrix analysis generated")
print("THREE-ARCHITECTURE PURE TRANSFORMER STUDY COMPLETED")
print("Ready for comprehensive ViT vs Swin vs EfficientViT comparative analysis")
# Out:
# CASME II EfficientViT Direct Baseline Confusion Matrix Generation
# =================================================================
# Found CASME II EfficientViT evaluation file: casme2_efficientvit_direct_evaluation_results.json
# Found EfficientViT wrong predictions file: casme2_efficientvit_direct_wrong_predictions.json
# Found 2 EfficientViT evaluation file(s)
# Successfully loaded EfficientViT evaluation results from: casme2_efficientvit_direct_evaluation_results.json
# Successfully loaded EfficientViT evaluation results from: casme2_efficientvit_direct_wrong_predictions.json
# EfficientViT Class Analysis:
#   Variant: m5
#   Available in test: ['others', 'disgust', 'happiness', 'repression', 'surprise', 'sadness']
#   Missing from test: ['fear']
# Processing EfficientViT confusion matrix for CASME II classes: ['others', 'disgust', 'happiness', 'repression', 'surprise', 'sadness', 'fear']
# EfficientViT variant: m5
# Confusion matrix shape: (7, 7)
# Calculated metrics - Macro F1: 0.1536, Weighted F1: 0.1596, Balanced Acc: 0.5180, Accuracy: 0.1786
# EfficientViT confusion matrix saved to: confusion_matrix_CASME2_EfficientViT_Direct.png
# EfficientViT per-class performance chart saved to: per_class_performance_CASME2_EfficientViT_Direct.png
# SUCCESS: EfficientViT visualization files generated successfully
#
# =================================================================
# CASME II EFFICIENTVIT MICRO-EXPRESSION RECOGNITION PERFORMANCE SUMMARY
# =================================================================
# Dataset: CASME_II
# Test samples: 28
# Model: EfficientViT_CASME2_Direct_Baseline
# Architecture: EfficientViT-M5 Cascaded Group Attention
# Evaluation date: 20250925_164625
#
# Overall Performance:
#   Accuracy:         0.1786
#   Macro Precision:  0.1583
#   Macro Recall:     0.2004
#   Macro F1:         0.1536
#   Macro AUC:        0.6465
#
# Per-Class Performance:
# Class        F1       Precision  Recall   AUC      Support  In Test
# -----------------------------------------------------------------
# others       0.0000   0.0000     0.0000   0.6111   10       Yes
# disgust      0.3636   0.5000     0.2857   0.7007   7        Yes
# happiness    0.2500   0.2500     0.2500   0.6875   4        Yes
# repression   0.0000   0.0000     0.0000   0.4800   3        Yes
# surprise     0.3077   0.2000     0.6667   0.7333   3        Yes
# sadness      0.0000   0.0000     0.0000   0.6667   1        Yes
# fear         0.0000   0.0000     0.0000   0.0000   0        No
#
# Training vs Test Comparison:
#   Training Val F1:  0.1352
#   Test F1:          0.1536
#   Performance Gap:  -0.0184
#   Best Epoch:       27
#   EfficientViT Variant: m5
#
# Class Availability Analysis:
#   Available classes: 6/7
#   Missing classes: ['fear']
#
# EfficientViT Architecture Details:
#   Variant: m5
#   Cascaded Group Attention: Memory efficient multi-head processing
#   Sandwich Layout: FFN-MHSA-FFN for improved efficiency
#   Attention Diversity: Different feature splits for each head
#
# Error Analysis:
#   Total errors: 23/28
#   Error rate: 82.14%
#
# Top Confusion Patterns:
#   others_to_surprise: 4 cases
#   others_to_repression: 4 cases
#   disgust_to_others: 2 cases
#
# Inference Performance:
#   Total time: 6.32s
#   Speed: 225.7 ms/sample
#
# =================================================================
# CASME II EFFICIENTVIT CONFUSION MATRIX GENERATION COMPLETED
# =================================================================
# Generated visualization files:
#   confusion_matrix_CASME2_EfficientViT_Direct.png
#   per_class_performance_CASME2_EfficientViT_Direct.png
#
# Final Performance Summary:
#   Architecture:     EfficientViT-M5
#   Accuracy:         0.1786
#   Macro F1:         0.1536
#   Weighted F1:      0.1596
#   Balanced Acc:     0.5180
#   Available classes: 6/7
#   Missing classes: 1
#
# Files saved in: /content/drive/MyDrive/RESEARCH-WORKSPACE/ACTIVE-PROJECTS/Thesis_MER_Project/results/02_03_efficientvit_direct/confusion_matrix_analysis
# Analysis completed at: 2025-09-25 16:46:28
#
# Cell 4 completed - CASME II EfficientViT confusion matrix analysis generated
# THREE-ARCHITECTURE PURE TRANSFORMER STUDY COMPLETED
# Ready for comprehensive ViT vs Swin vs EfficientViT comparative analysis
